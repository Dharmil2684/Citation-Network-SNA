# %%
import requests
import time
import json
import os

# File path to store citation data
DATA_FILE = "IIT_citation_data.json"

# Function to fetch citation data for a given paper ID with retries
def fetch_citations(paper_id, max_retries=3):
    url = f"https://api.semanticscholar.org/graph/v1/paper/{paper_id}?fields=title,authors,citations.paperId,citations.title,citations.authors"

    for attempt in range(max_retries):
        try:
            response = requests.get(url, timeout=10)

            if response.status_code == 200:
                return response.json()
            elif response.status_code == 429:  # Rate limit exceeded
                wait_time = 2 ** attempt  # Exponential backoff
                print(f"Rate limit hit. Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
            else:
                print(f"Error {response.status_code} for {paper_id}: {response.text}")
                return None

        except requests.exceptions.RequestException as e:
            print(f"Request failed (Attempt {attempt+1}/{max_retries}): {e}")
            time.sleep(2)  # Small delay before retrying

    print(f"Failed to fetch data for {paper_id} after {max_retries} attempts.")
    return None

# Load existing data if available
def load_existing_data():
    if os.path.exists(DATA_FILE):
        with open(DATA_FILE, "r") as file:
            try:
                return json.load(file)
            except json.JSONDecodeError:
                print("Error loading existing data. Starting fresh.")
                return {}
    return {}

# Save data to a file
def save_data(data):
    with open(DATA_FILE, "w") as file:
        json.dump(data, file, indent=4)

# Root paper IDs
root_paper_ids = [
    "c3935b75b1f747864a07cc2a99b0b8fdcb34c26a",  # Paper 1
    "0b0feefb1d22078ea6e7ebc01801f7d179ed970c"   # Paper 2
]

# Load previously saved data
citation_data = load_existing_data()

# Fetch citation data for each paper if not already saved
for root_paper_id in root_paper_ids:
    if root_paper_id in citation_data:
        print(f"Data for {root_paper_id} already exists. Skipping fetch.")
        continue

    citation_dict = {} 
    author_dict = {}
    citation_edges = []
    id_arr = [root_paper_id]  # Queue for BFS-like processing

    # Set a time limit (3 minutes = 180 seconds)
    start_time = time.time()

    while id_arr:
        elapsed_time = time.time() - start_time
        if elapsed_time > 180:  
            print(f"Time limit exceeded for {root_paper_id}. Stopping collection.")
            break
        
        paper_id = id_arr.pop(0)  
        data = fetch_citations(paper_id)

        if data:
            paper_title = data.get("title", "Unknown Paper")
            authors = [author.get("name", "Unknown Author") for author in data.get("authors", [])]

            citation_dict[paper_id] = paper_title  
            author_dict[paper_id] = authors  # Store authors

            print(f"\nCiting Papers for: {paper_title} (ID: {paper_id})")
            print(f"Authors: {', '.join(authors)}")

            for citation in data.get("citations", []):
                cited_paper_id = citation.get("paperId")
                cited_paper_title = citation.get("title", "Unknown Title")
                cited_authors = [author.get("name", "Unknown Author") for author in citation.get("authors", [])]

                if cited_paper_id and cited_paper_title:
                    if cited_paper_id not in citation_dict:
                        citation_dict[cited_paper_id] = cited_paper_title
                        author_dict[cited_paper_id] = cited_authors
                        id_arr.append(cited_paper_id)  

                    citation_edges.append([cited_paper_id, paper_id])  

                    print(f"{cited_paper_title} (ID: {cited_paper_id})")
                    print(f"Authors: {', '.join(cited_authors)}")

        time.sleep(5)

    citation_data[root_paper_id] = {
        "dict": citation_dict, 
        "authors": author_dict, 
        "edges": citation_edges
    }

    save_data(citation_data)

print("\nFinished fetching citations for all papers.")
# Out:
# Rate limit hit. Retrying in 1 seconds...
#
# Citing Papers for: Processor modeling for hardware software codesign (ID: c3935b75b1f747864a07cc2a99b0b8fdcb34c26a)
# Authors: V. Rajesh, R. Moona
# ISADL: An Instruction Set Architecture Description Language for VLIW (ID: 818de5cf1c0c60e166ac3a8d948fa59c82d21806)
# Authors: Xin Xiao, Zhong Liu
# Processor Modeling and Design Tools (ID: 3a7d0340c5a8b54d726d3396df25d9585efbeaf3)
# Authors: A. Chattopadhyay, N. Dutt, R. Leupers, P. Mishra
# A constraint-based WCET computation framework (ID: d994b7a7e8687eead59d1a9bcdd0649dd3f2bc78)
# Authors: Hajer Herbegue, M. Filali, H. Cassé
# Hardware architecture specification and constraint-based WCET computation (ID: 6f7105f41b189410a6f1e175fc2e9f0fe94dbb95)
# Authors: Hajer Herbegue, H. Cassé, M. Filali, Christine Rochange
# Using the CASM language for simulator synthesis and model verification (ID: 6e85b5b82b0cee627feb560b997c4d8791b8e0f4)
# Authors: Roland Lezuo, A. Krall
# Harmless, a hardware architecture description language dedicated to real-time embedded system simulation (ID: b13589b7555c8113367147a3547b61f89bfe8d18)
# Authors: Rola Kassem, M. Briday, Jean-Luc Béchennec, G. Savaton, Y. Trinquet
# C Compilers for ASIPs: Automatic Compiler Generation with LISA (ID: 4c0cec7bac1065c89b13a6a9e0b61f36c14f800d)
# Authors: M. Hohenauer, R. Leupers
# Automatic generation of memory interfaces (ID: 45ede6747d25898b56da76e89cdcfe38f9db9980)
# Authors: D. Kammler, E. M. Witte, A. Chattopadhyay, Bastian Bauwens, G. Ascheid, R. Leupers, H. Meyr
# A versatile generator of instruction set simulators and disassemblers (ID: 49874e52934536af65a47fd7af68f065571ba48f)
# Authors: Tahiry Ratsiambahotra, H. Cassé, P. Sainrat
# Performance Estimation: IPC (ID: edd40a31bc781927f32231eb827b80457214fa08)
# Authors: A. Ray, Jigang Wu, T. Srikanthan
# MiADL : linguagem para geração automática de simuladores redireccionáveis (ID: 11c6be0a13b6a799ecc680fb0029270798bac14e)
# Authors: J. Metrôlho
# Processor Description Languages (ID: 9e4f70e357319cdaab1af7ba8251e98dc9ed321b)
# Authors: P. Mishra, N. Dutt
# Cache-Analyzer: Design Space Evaluation of Configurable-Caches in a Single-Pass (ID: 07d465530e0f76d72d2f9da7e12995189218b811)
# Authors: André Silva, Guilherme Esmeraldo, E. Barros, Pablo Viana
# Generic Processor Modeling for Automatically Generating Very Fast Cycle-Accurate Simulators (ID: 031cc53193d5ebeb0ea6eaa9825076ba5dbcfacd)
# Authors: Mehrdad Reshadi, B. Gorjiara, N. Dutt
# Modélisation du logiciel embarqué à différents niveaux d'abstraction en vue de la validation et la synthèse des systèmes monopuces (ID: efd32d2ca54f7e2bf538bcb15fb43df0f0083c5a)
# Authors: A. Bouchhima
# Estimating processor performance of library function (ID: 374a040553279f4923bbfaa4ef6e20d2b0a4b233)
# Authors: A. Ray, W. Jigang, S. Thambipillai
# Simulação compilada para arquiteturas descritivas em ArchC (ID: 47896d2fbe1a78e88bd96eddad61fe249cfd94da)
# Authors: Marcus Bartholomeu, R. Azevedo
# Practical techniques for performance estimation of processors (ID: 16fdcbfb152f92e92c5b55791cbc8590606e85cb)
# Authors: A. Ray, T. Srikanthan, W. Jigang
# Architecture description languages for programmable embedded systems (ID: bdec376a708b925d235aefcdd748f5c8dca8bc88)
# Authors: P. Mishra, N. Dutt
# Generic pipelined processor modeling and high performance cycle-accurate simulator generation (ID: 92e247b6c18ef5d3c539c281fcf33b27388bb854)
# Authors: Mehrdad Reshadi, N. Dutt
# A framework for automated and optimized ASIP implementation supporting multiple hardware description languages (ID: 36906392fb7c4ea483c5abdfcbd6d76663e01bb6)
# Authors: O. Schliebusch, A. Chattopadhyay, D. Kammler, G. Ascheid, R. Leupers, H. Meyr, Tim Kogel
# A methodology and tooling enabling application specific processor design (ID: e3ae9df072166717e9bd7428c8547e9c52a42fab)
# Authors: A. Hoffmann, F. Fiedler, A. Nohl, Surender Parupalli
# ASIP architecture exploration for efficient IPSec encryption: A case study (ID: 958a1d76008088652022992ae41178ce4ca8b4cc)
# Authors: H. Scharwächter, D. Kammler, Andreas Wieferink, M. Hohenauer, K. Karuri, J. Ceng, R. Leupers, G. Ascheid, H. Meyr
# C compiler aided design of application specific instruction set processors using the machine description language LISA (ID: 7a392b8644dc3159e36f321c5eb99ccec51ba531)
# Authors: Oliver Wahlen
# RTL processor synthesis for architecture exploration and implementation (ID: b5466b880805bd50205bd587994ffe0ebb273e76)
# Authors: O. Schliebusch, A. Chattopadhyay, R. Leupers, G. Ascheid, H. Meyr, M. Steinert, G. Braun, A. Nohl
# Processor-memory coexploration using an architecture description language (ID: 751c398dbe3d481dc8273111bfe5d374af1936dc)
# Authors: P. Mishra, M. Mamidipaka, N. Dutt
# Modeling and validation of pipeline specifications (ID: d105ac41773618f77c26054d125f529a3507402d)
# Authors: P. Mishra, N. Dutt
# DiST: a simple, reliable and scalable method to significantly reduce processor architecture simulation time (ID: 7eec786beea40fc1eeef11f2702b9c22498b64b1)
# Authors: Sylvain Girbal, Gilles Mouchard, Albert Cohen, O. Temam
# Retargetable Program Profiling Using High Level Processor Models (ID: a444c4e51bdfb8d703ab7c1248293cc8e3ed686e)
# Authors: Rajiv A. Ravindran, R. Moona
# A novel methodology for the design of application-specificinstruction-set processors (ASIPs) using a machine description language (ID: 8b7dee7446c0b1b5317e319d643a032561016e99)
# Authors: A. Hoffmann, Tim Kogel, A. Nohl, G. Braun, O. Schliebusch, Oliver Wahlen, Andreas Wieferink, H. Meyr
# Using static scheduling techniques for the retargeting of high speed, compiled simulators for embedded processors from an abstract machine description (ID: 2502386f52cbcc59f48fc24ae4179e85210aeb79)
# Authors: G. Braun, A. Hoffmann, A. Nohl, H. Meyr
# Functional abstraction driven design space exploration of heterogeneous programmable architectures (ID: 7dc4b2cfc190a9d792d51e0869c2e2141a8654c4)
# Authors: P. Mishra, N. Dutt, A. Nicolau
# V-SAT: a visual specification and analysis tool for system-on-chip exploration (ID: dcee2814ede899b1e924ffe5f16a1d4345f63ba1)
# Authors: A. Khare, Ashok Halambi, N. Savoiu, P. Grun, N. Dutt, A. Nicolau
# Retargetable cache simulation using high level processor models (ID: 0009ad568d7e6f2a65fbd0bf03b2544950fedcbb)
# Authors: Rajiv A. Ravindran, R. Moona
# Processor-memory co-exploration driven by a Memory-Aware Architecture Description Language (ID: cd848bc20c4ba167344394f446c581d5b4e782c9)
# Authors: P. Mishra, P. Grun, N. Dutt, A. Nicolau
# Retargetable compiled simulation of embedded processors using a machine description language (ID: 88d04329b21dcb3c2c1584f11232f956e0c03e87)
# Authors: S. Pees, A. Hoffmann, H. Meyr
# Retargetable functional simulator using high level processor models (ID: 9e48845831dcb91243a01cb3d88c70605b1c42ed)
# Authors: Subhash Chandra, R. Moona
# Approche ADL pour la modélisation d'architecture basée sur les contraintes (calcul de WCET) (ID: 6d5986ef3e16b1fb5efe8da4a0b56c51187334d1)
# Authors: Hajer Herbegue
# Formal specification of the x86 instruction set architecture (ID: e9b39d468b8431d754c5c0b6ffc4c3867dcf4e33)
# Authors: Ulan Degenbaev
# Rapid Techniques for Performance Estimation of Processors (ID: 5f0866f3df99fd62fa70cfdb481b760198d0f51a)
# Authors: A. Ray, T. Srikanthan, Jigang Wu
# Embedded Processor Selection/Performance Estimation using FPGA-based Profiling (ID: 622aa0ea71c9a5346d6a863e4d7be758338837d1)
# Authors: Fadi Obeidat
# C Compilers for ASIPs (ID: 6da1cb672ddb23003af156c1aebb94533c23e0fb)
# Authors: M. Hohenauer, R. Leupers
# Retargetable code generation based on an architecture description language (ID: b7aa3736a00d98321c0ac04ccf2d28a7be7b4e91)
# Authors: M. Hohenauer
# HMDES, ISDL, and Other Contemporary ADLs (ID: e36ccd9605635efa3e09dc76e7ce26d24d24faf2)
# Authors: N. Bandyopadhyay, K. Basu, P. Mishra
# Disassembly and Parsing Support for Retargetable Tools Using Sim-nML (ID: b06f21488b8d353cee30727159ca630eb2a9b896)
# Authors: Nitin Kumar Dahra
# Uma metodologia para exploração do espaço de projeto de hierarquias de memória para sistemas embarcados (ID: 892c265edf130e4b908e52526638a57aa259b90f)
# Authors: P. Silva
# Electronic Design Automation for Integrated Circuits Handbook (ID: 373c9987d721e0bfb3a9527a135598e54ac9a794)
# Authors: L. Scheffer, L. Lavagno, G. Martin
# A Novel Methodology for the Design of Application-Specific Instruction-Set Processors (ID: 48e9f20dbda5fc3b96e0ef4e018998d48f34bedb)
# Authors: A. Nohl, G. Braun, A. Hoffmann
# A framework for automated and optimized ASIP implementation supporting multiple hardware description languages (ID: 43459af50ad3e3d158f3190e01794521273f1e7e)
# Authors: O. Schliebusch, A. Chattopadhyay, D. Kammler, G. Ascheid, R. Leupers, H. Meyr, T. Kogel
# Retargetable Instruction Selection and Generation of GCC Back-end Using High-level Processor Models (ID: beb3dc920503e92ed3f3069df9c266ec8b592686)
# Authors:
# Specification-driven validation of programmable embedded systems (ID: e7d2755eecfc53ff3a48f3d8113e84bea7c63534)
# Authors: P. Mishra, N. Dutt
# These de Doctorat de l'Universite de Nantes (ID: cfe8ceede4b08b88a6efaef279f87b87d35ca7ad)
# Authors: École Doctorale, Mohammed V-Agdal
# Architecture Description Language Driven Validation of Dynamic Behavior in Pipelined Processor Specifications (ID: b31f5e49d2d229d771212cc1b163ad7a240f42f1)
# Authors: P. Mishra, N. Dutt, H. Tomiyama
# A Framework for Memory Subsystem Exploration (ID: 17ec268d0fd1c99d30ec2647cb787658e364d2cc)
# Authors: P. Mishra, M. Mamidipaka, N. Dutt
# Modeling embedded processors and generating fast simulators using the machine description language LISA (ID: 1f84f0d9dc22d24ede8e5f25ebed0c6ac2fe7a35)
# Authors: S. Pees
# Coprocessor Codesign for Programmable Architectures (ID: 5ecb5c618b901a3012eb94a0091cbf13f9608e09)
# Authors: P. Mishra, F. Rousseau, N. Dutt
# Specification of Hazards, Stalls, Interrupts, and Exceptions in EXPRESSION (ID: 1827bafc6179771b76410010ee6d3bfa38e30c83)
# Authors: P. Mishra, N. Dutt, A. Nicolau
# Memory Subsystem Description in EXPRESSION (ID: ecd67d94b94d0bceaecfec452e4f46e7848eb082)
# Authors: P. Mishra, P. Grun, N. Dutt, A. Nicolau
# SIMPRESS: A Simulator Generation Environment for System-on-Chip Exploration (ID: d820fca7aff45f990b4e7e5b55180060240bad93)
# Authors: A. Khare
# Disassembler using High Level Processor Models (ID: 4cdd820215193c74fdcb9eeb5e0d499dcb0bb98a)
# Authors: Nihali Jain
# Architecture Description Language Driven Verification of In-order Execution in Pipelined Processors (ID: 0b3302fcf45fd5c786589ecc7970faa74d075b9f)
# Authors: Prabhat Mishra, H. Tomiyama, N. Dutt, Alex Nicolau
# Rate limit hit. Retrying in 1 seconds...
# Rate limit hit. Retrying in 2 seconds...
# Rate limit hit. Retrying in 4 seconds...
# Failed to fetch data for 818de5cf1c0c60e166ac3a8d948fa59c82d21806 after 3 attempts.
#
# Citing Papers for: Processor Modeling and Design Tools (ID: 3a7d0340c5a8b54d726d3396df25d9585efbeaf3)
# Authors: A. Chattopadhyay, N. Dutt, R. Leupers, P. Mishra
# Rate limit hit. Retrying in 1 seconds...
# Rate limit hit. Retrying in 2 seconds...
#
# Citing Papers for: A constraint-based WCET computation framework (ID: d994b7a7e8687eead59d1a9bcdd0649dd3f2bc78)
# Authors: Hajer Herbegue, M. Filali, H. Cassé
# Formal Architecture Specification for Time Analysis (ID: 885721a1699906f243ddbd970cdaee561c3c6e6a)
# Authors: Hajer Herbegue, M. Filali, H. Cassé
# Architecture of Computing Systems – ARCS 2014 (ID: 178b16f7ac6187938d2ebf4a50286e10eb2af778)
# Authors: E. Maehle, K. Römer, Wolfgang Karl, E. Tovar
# Approche ADL pour la modélisation d'architecture basée sur les contraintes (calcul de WCET) (ID: 6d5986ef3e16b1fb5efe8da4a0b56c51187334d1)
# Authors: Hajer Herbegue
# Rate limit hit. Retrying in 1 seconds...
#
# Citing Papers for: Hardware architecture specification and constraint-based WCET computation (ID: 6f7105f41b189410a6f1e175fc2e9f0fe94dbb95)
# Authors: Hajer Herbegue, H. Cassé, M. Filali, Christine Rochange
# Build Your Own Static WCET analyser: the Case of the Automotive Processor AURIX TC275 (ID: a4f9267b6051d0c73d836d3f7cd1e302ace795b3)
# Authors: Wei-Tsun Sun, E. Jenn, H. Cassé
# Worst-Case Reaction Time Optimization on Deterministic Multi-Core Architectures with Synchronous Languages (ID: 21ab9ccd4609e289a24d1da279ace5eb75796f33)
# Authors: Nicolas Hili, A. Girault, E. Jenn
# Ensuring Consistency between Cycle-Accurate and Instruction Set Simulators (ID: 7423603fac7e8965e507a4fb28e36fd41ed1e071)
# Authors: F. Jebali, D. Potop-Butucaru
# Formal Architecture Specification for Time Analysis (ID: 885721a1699906f243ddbd970cdaee561c3c6e6a)
# Authors: Hajer Herbegue, M. Filali, H. Cassé
# A constraint-based WCET computation framework (ID: d994b7a7e8687eead59d1a9bcdd0649dd3f2bc78)
# Authors: Hajer Herbegue, M. Filali, H. Cassé
# 20th International Workshop on Worst-Case Execution Time Analysis, WCET 2022, July 5, 2022, Modena, Italy (ID: e05561386b5e1f2463a7fab73ce67c5ee87bdcbc)
# Authors: M. Jacobs, N. Hölscher, J. Reineke
# DELOOP: Automatic Flow Facts Computation Using Dynamic Symbolic Execution (ID: 59e711eb904ec6594cff3427083cc424615826df)
# Authors: Hazem Abaza, Zain Alabedin Haj Hammadeh, D. Lüdtke
# Architecture of Computing Systems – ARCS 2014 (ID: 178b16f7ac6187938d2ebf4a50286e10eb2af778)
# Authors: E. Maehle, K. Römer, Wolfgang Karl, E. Tovar
# Approche ADL pour la modélisation d'architecture basée sur les contraintes (calcul de WCET) (ID: 6d5986ef3e16b1fb5efe8da4a0b56c51187334d1)
# Authors: Hajer Herbegue
# Rate limit hit. Retrying in 1 seconds...
#
# Citing Papers for: Using the CASM language for simulator synthesis and model verification (ID: 6e85b5b82b0cee627feb560b997c4d8791b8e0f4)
# Authors: Roland Lezuo, A. Krall
# CASM-IR: Uniform ASM-Based Intermediate Representation for Model Specification, Execution, and Transformation (ID: 88ab94dde3f6b2325288866d29a4392f26be1cb1)
# Authors: P. Paulweber, Emmanuel Pescosta, Uwe Zdun
# A Model-Based Transformation Approach to Reuse and Retarget CASM Specifications (ID: b4bccb16ab62b73e1a7de9d8e22703cc2d2d899e)
# Authors: P. Paulweber, Uwe Zdun
# CASM: optimized compilation of abstract state machines (ID: f9099ad7540769be36c37d55aae0218674d501d1)
# Authors: Roland Lezuo, P. Paulweber, A. Krall
# CASM: Implementing an Abstract State Machine based Programming Language (ID: 68d55dc2020fb33d9704782083243cd0d3b01d71)
# Authors: Roland Lezuo, Gergö Barany, A. Krall
# Rate limit hit. Retrying in 1 seconds...
#
# Citing Papers for: Harmless, a hardware architecture description language dedicated to real-time embedded system simulation (ID: b13589b7555c8113367147a3547b61f89bfe8d18)
# Authors: Rola Kassem, M. Briday, Jean-Luc Béchennec, G. Savaton, Y. Trinquet
# Flexible Generation of Fast and Accurate Software Performance Simulators From Compact Processor Descriptions (ID: 349862072f21def2a58e8947a3cdcec338f06de9)
# Authors: Conrad Foik, Robert Kunzelmann, Daniel Mueller-Gritschneder, Ulf Schlichtmann
# CorePerfDSL: A Flexible Processor Description Language for Software Performance Simulation (ID: dc3452b872d47368ec91ec68784f5b533af45d76)
# Authors: Conrad Foik, Daniel Mueller-Gritschneder, Ulf Schlichtmann
# Domain-specific programming assistance in an embedded DSL for generating processor emulators (ID: 84664b3e75b9e661c08307067b34d9679d14daed)
# Authors: Katsumi Okuda, S. Chiba
# A PROCESS MODEL FOR THE FORMALISATION OF QUALITY ATTRIBUTES OF SERVICE-BASED SOFTWARE SYSTEMS (ID: 84d46685878c35a57b7896f8d54bac4ccb852a1f)
# Authors: M. Lall, L. Venter, J. A. V. D. Poll
# BEST: a Binary Executable Slicing Tool (ID: f854f74ddcdd5bc3c186205d30bf20b9c1624ff6)
# Authors: Armel Mangean, Jean-Luc Béchennec, M. Briday, Sébastien Faucou
# Decision tree generation for decoding irregular instructions (ID: 77ccd9be2e6a7f6dc35dd30d9ddb1d677afe6ee4)
# Authors: Katsumi Okuda, Haruhiko Takeyama
# From high level architecture descriptions to fast instruction set simulators (ID: 58b012d8b6bff446c90f6755f8cfff76670c34a5)
# Authors: Harry Wagstaff
# Simulation efficace d'architectures opérationnelles (ID: 6b2588f0680a086dd760b1c4e28269681c2cebdb)
# Authors: Adrien Bullich
# Automated ISA branch coverage analysis and test case generation for retargetable instruction set simulators (ID: bb5ecdb6b80b8caae2c77c4343eeff211cd35d8b)
# Authors: Harry Wagstaff, T. Spink, Björn Franke
# Improving processor hardware compiled cycle accurate simulation using program abstraction (ID: 8d68b7f29acdcc39e5fc08a57ce75e47693cde0d)
# Authors: B. Adrien, Briday Mikaël, Béchennec Jean-Luc, Trinquet Yvon
# ComCas: A Compiled Cycle Accurate Simulation for Hardware Architecture (ID: 995604e2c502cd673a0f5f0aa57829b141d1fce7)
# Authors: Adrien Bullich, M. Briday, Jean-Luc Béchennec, Y. Trinquet
# Automated generation of dynamic binary translators for instruction set simulation (ID: 249833d37a9a6ffe73062b9af15d76e9e72e29f7)
# Authors: Katsumi Okuda, Minoru Yoshida, Haruhiko Takeyama, M. Nakamura
# Virtual Prototyping of Embedded Systems: Speed and Accuracy Tradeoffs (ID: 10970fda628322438d0acb16ddd295d2bea8309a)
# Authors: V. Joloboff, A. Gerstlauer
# Improving processor hardware compiled cycle accurate simulation using program abstraction (ID: 7d34d75371ba2231669b5385caa707763426f064)
# Authors: Adrien Bullich, M. Briday, Jean-Luc Béchennec, Y. Trinquet
# Instant Simulator : A tool for generating simulators from machine-readable descriptions (ID: b9d83b40f05999c4559dc9c989da863960198032)
# Authors: Karl-Anders Johansson
# Approche ADL pour la modélisation d'architecture basée sur les contraintes (calcul de WCET) (ID: 6d5986ef3e16b1fb5efe8da4a0b56c51187334d1)
# Authors: Hajer Herbegue
#
# Citing Papers for: C Compilers for ASIPs: Automatic Compiler Generation with LISA (ID: 4c0cec7bac1065c89b13a6a9e0b61f36c14f800d)
# Authors: M. Hohenauer, R. Leupers
# Compiler-Centred Microprocessor Design (CoMet) - From C-Code to a VHDL Model of an ASIP (ID: 4674322793c1b3bf98fa56e8b4fd4b55b3069e44)
# Authors: Roberto Urban, Mario Schölzel, H. Vierhaus, E. Altmann, Horst Seelig
# Authors: Hani H. Alyazidi
# Strategic Technology Options in the Wireless Industry: A Case Study for U.S. Wireless Carriers (ID: ae5472e8b1debce22c448dfec0f180c721d2aa5b)
# Authors: H. Kim, Marin B. Weiss, B. Morel
# Time-Based Confidentiality Enhancement Scheme for Mobile Wireless Networks (ID: d5c4d69e3fa103c4d33fafa63c78bb6436b3eeb1)
# Authors: Qunwei Zheng, X. Hong, Jun Liu, Lei Tang
#
# Citing Papers for: A versatile generator of instruction set simulators and disassemblers (ID: 49874e52934536af65a47fd7af68f065571ba48f)
# Authors: Tahiry Ratsiambahotra, H. Cassé, P. Sainrat
# Build Your Own Static WCET analyser: the Case of the Automotive Processor AURIX TC275 (ID: a4f9267b6051d0c73d836d3f7cd1e302ace795b3)
# Authors: Wei-Tsun Sun, E. Jenn, H. Cassé
# Validating Static WCET Analysis: A Method and Its Application (ID: 1b02d32d5ae4abcbbfbeb4159464223c27eed14b)
# Authors: Wei-Tsun Sun, E. Jenn, H. Cassé
# Decision tree generation for decoding irregular instructions (ID: 77ccd9be2e6a7f6dc35dd30d9ddb1d677afe6ee4)
# Authors: Katsumi Okuda, Haruhiko Takeyama
# Introduction to functional approach in reverse engineering using F# language (ID: ddf61cf38ba2183c4bee15b5969a2ee4599f7401)
# Authors: Jan Sadolewski
# Hardware architecture specification and constraint-based WCET computation (ID: 6f7105f41b189410a6f1e175fc2e9f0fe94dbb95)
# Authors: Hajer Herbegue, H. Cassé, M. Filali, Christine Rochange
# Harmless, a hardware architecture description language dedicated to real-time embedded system simulation (ID: b13589b7555c8113367147a3547b61f89bfe8d18)
# Authors: Rola Kassem, M. Briday, Jean-Luc Béchennec, G. Savaton, Y. Trinquet
# WCET TOOL CHALLENGE 2011: REPORT (ID: 9133e3e0887e842cbd892de331152bdd9c2e1dd3)
# Authors: R. V. Hanxleden, N. Holsti, B. Lisper, E. Ploedereder, R. Wilhelm, Armelle Bonenfant, H. Cassé, Sven Bünte, Wolfgang Fellger, S. Gepperth, J. Gustafsson, Benedikt Huber, Nazrul Islam, Daniel Kästner, R. Kirner, L. Kovács, F. Krause, M. D. Michiel, Mads Christian Olesen, A. Prantl, Wolfgang Puffitsch, Christine Rochange, Martin Schoeberl, Simon Wegener, Michael Zolda, Jakob Zwirchmayr
# OTAWA: An Open Toolbox for Adaptive WCET Analysis (ID: 12ddfb2013c4f9d363105fdb97b56d6b1bf86d09)
# Authors: C. Ballabriga, H. Cassé, Christine Rochange, P. Sainrat
# A design flow for critical embedded systems (ID: 4105785a9e074392892faea75f28e8d4d894f17a)
# Authors: Vincent Lefftz, Jean Bertrand, H. Cassé, Christophe Clienti, P. Coussy, L. Maillet-Contoz, Philippe Mercier, P. Moreau, L. Pierre, E. Vaumorin
# Experimentation of WCET computation on both ends of automotive processor range (ID: 2499540df4caf95f7363fa1f6ec1d15261b4fef8)
# Authors: H. Cassé, P. Sainrat, C. Ballabriga, M. D. Michiel
# FAST INSTRUCTION-ACCURATE SIMULATION WITH SIMNML (ID: 8c10af436b51287457c93a576606214ff7e5476f)
# Authors: H. Cassé, J. Barre, Rodolphe Vaillant, P. Sainrat
#
# Citing Papers for: Performance Estimation: IPC (ID: edd40a31bc781927f32231eb827b80457214fa08)
# Authors: A. Ray, Jigang Wu, T. Srikanthan
# Performance Prediction of HPC Applications on Intel Processors (ID: bd337fb6e8ea9608e1bd043499c1a0127a2e8595)
# Authors: C. Rosales, A. Gómez-Iglesias, Si Liu, Feng Chen, Lei Huang, Hang Liu, A. Lamas-Linares, J. Cazes
# Rate limit hit. Retrying in 1 seconds...
# Rate limit hit. Retrying in 2 seconds...
#
# Citing Papers for: MiADL : linguagem para geração automática de simuladores redireccionáveis (ID: 11c6be0a13b6a799ecc680fb0029270798bac14e)
# Authors: J. Metrôlho
#
# Citing Papers for: Processor Description Languages (ID: 9e4f70e357319cdaab1af7ba8251e98dc9ed321b)
# Authors: P. Mishra, N. Dutt
# Using the Abstract Computer Architecture Description Language to Model AI Hardware Accelerators (ID: 2d771b9170382a8bfece9f2df2bcfb614ecd3c7d)
# Authors: Mika Markus Müller, Alexander Richard Manfred Borst, Konstantin Lübeck, Alexander Louis-Ferdinand Jung, Oliver Bringmann
# OpenASIP 2.0: Co-Design Toolset for RISC-V Application-Specific Instruction-Set Processors (ID: 5a79ac89161d96103c7216844ca3bea5a04252c2)
# Authors: Kari Hepola, Joonas Multanen, P. Jääskeläinen
# Inferring Custom Synthesizable Kernel for Generation of Coprocessors with Out-of-Order Execution (ID: c22a5f0ff82838ecc52de7c0e731844f022436a0)
# Authors: Alexander P. Antonov
# An Agile Instruction Set Extension Method Based on the RISC-V Processor (ID: 56567a73f02900b80c4e41061efca1432e6c1da1)
# Authors: Bowen Hu, Yun Chen, Xiaoyang Zeng
# Domain-specific programming assistance in an embedded DSL for generating processor emulators (ID: 84664b3e75b9e661c08307067b34d9679d14daed)
# Authors: Katsumi Okuda, S. Chiba
# Early Verification of ISA Extension Specifications using Deep Reinforcement Learning (ID: 2c16afb902f4e8b7861691b6c9eefddd49b79b11)
# Authors: Niklas Bruns, Daniel Große, R. Drechsler
# The Approach to Design of Problem-Oriented Reconfigurable Hardware Computational Units (ID: eafc3ccc7393934bd6b3b782fc89611a4a5c6a02)
# Authors: V. Pinkevich, A. Platunov, A. Penskoi
# Verification of the CAD System for an Application-Specific Processor by Property-Based Testing (ID: 0ae8d54189673716db628ba09706b0e5eac97f36)
# Authors: D. Prohorov, A. Penskoi
# Rigorous engineering for hardware security: Formal modelling and proof in the CHERI design and implementation process (ID: 3e698bd33e438570a171de6b78e01506a1245110)
# Authors: Kyndylan Nienhuis, Alexandre Joannou, Thomas Bauereiß, A. Fox, M. Roe, B. Campbell, Matthew Naylor, Robert M. Norton, S. Moore, P. Neumann, I. Stark, R. Watson, Peter Sewell
# Iterative Algorithm for Multidimensional Pareto Frontiers Intersection Determination (ID: c33865202676ab44148d12bb0dcf26f98cf20852)
# Authors: Jakub Podivinsky, Ondrej Cekan, Martin Krcma, Radek Burget, Tomás Hruska, Z. Kotásek
# Multidimensional Pareto Frontiers Intersection Determination and Processor Optimization Case Study (ID: 71ca11dc2c29830329e899a30b327aa6188f9e31)
# Authors: Jakub Podivinsky, Ondrej Cekan, Martin Krcma, Radek Burget, Tomás Hruska, Z. Kotásek
# ISA semantics for ARMv8-a, RISC-v, and CHERI-MIPS (ID: 6c0b3cf08490a0bf6a5e0850a66c329eb6e7fd9e)
# Authors: A. Armstrong, Thomas Bauereiß, B. Campbell, A. Reid, Kathryn E. Gray, Robert M. Norton, Prashanth Mundkur, Mark Wassell, Jon French, Christopher Pulte, Shaked Flur, I. Stark, N. Krishnaswami, Peter Sewell
# A Processor Optimization Framework for a Selected Application (ID: becc891a7548fe38a15b224e2592d97dd0efe31e)
# Authors: J. Podivínský, Ondrej Cekan, Martin Krcma, Radek Burget, Tomás Hruska, Z. Kotásek
# Maintaining ISA Specifications in MicroTESK Test Program Generator (ID: b6e53b717e5c7fa70e9c2762f2fe5cf5aa1b546e)
# Authors: M. Chupilko, A. Kamkin, A. Kotsynyak, Alexander Protsenko, S. Smolov, A. Tatarnikov
# Constructing Fast and Cycle-Accurate Simulators for Configurable Accelerators Using C++ Templates (ID: a133b8bbd3db1358bdce431a3e3564fc4bc11962)
# Authors: Michael Witterauf, Frank Hannig, J. Teich
# Automatic instruction-set architecture synthesis for VLIW processor cores in the ASAM project (ID: 6cd87e95bcb117d2e0f515e36d520b523367d685)
# Authors: Roel Jordans, L. Józwiak, H. Corporaal, R. Corvino
# An integrated concurrency and core-ISA architectural envelope definition, and test oracle, for IBM POWER multiprocessors (ID: e448f2dba68a805f2735707125d10f08a27c2aa4)
# Authors: Kathryn E. Gray, Gabriel Kerneis, Dominic P. Mulligan, Christopher Pulte, Susmit Sarkar, Peter Sewell
# Instruction-set architecture synthesis for VLIW processors (ID: 092c4f12b2d1bc894673d38b52e9efc7c064abe6)
# Authors: Roel Jordans
# Live Introspection of Target-Agnostic JIT in Simulation (ID: f37b93278eebe4c3871779a57b4d9a9d351483c9)
# Authors: Boris Shingarov
# Using ArchC to model a Hard-PLC processor (ID: dd3f2476b24740d8e145c2708cba75b6449fc1e9)
# Authors: Johannes Kohl, D. Fey, J. Basig
# Contributions à la traduction binaire dynamique : support du parallélisme d'instructions et génération de traducteurs optimisés. (Contributions to dynamic binary translation : instruction parallelism support and optimized translators generator) (ID: 766445ccb38a1d17f2a5a20d176d696850a1969c)
# Authors: Lucy Michel
# Fast Simulation of Pipeline in ASIP Simulators (ID: 9ef75278f7d450b9dd460e7b114e458b5c417a7d)
# Authors: Zdenek Prikryl
# Modern Software Tools for New Computing Architectures Development (ID: d399789d84f862b58386324cd6ab46c933569304)
# Authors: A. Drozdov, S. Novikov, V. Vladislavlev, Yuriy N. Fonin
# Verifying micro-architecture simulators using event traces (ID: 4702fa61e7b1c2da2c5f5174d34d96fe26dccb8d)
# Authors: Hui Meen Nyew, Nilufer Onder, Soner Önder, Zhenlin Wang
# Improving processor hardware compiled cycle accurate simulation using program abstraction (ID: 8d68b7f29acdcc39e5fc08a57ce75e47693cde0d)
# Authors: B. Adrien, Briday Mikaël, Béchennec Jean-Luc, Trinquet Yvon
# DHASER: Dynamic heterogeneous adaptation for soft-error resiliency in ASIP-based multi-core systems (ID: d7fb46ca7dd396754cea75298ce50bcc1ae84f0b)
# Authors: Tuo Li, M. Shafique, Semeen Rehman, Jude Angelo Ambrose, J. Henkel, S. Parameswaran
# Automated generation of efficient instruction decoders for Instruction Set Simulators (ID: 28db64c236b493f9863461596322e803e2b584b2)
# Authors: Nicolas Fournel, Luc Michel, F. Pétrot
# SoC performance evaluation with ArchC and TLM-2.0 (ID: 3f73827f3693aa9dd5bfad102cbbc8ad2b051289)
# Authors: Jörg Walter, Jörg Lenhardt, W. Schiffmann
# A First-Order Logic Based Framework for Verifying Simulations (ID: fa9b128bd9bb1275c720c3b9f474a602afc843ed)
# Authors: Hui Meen Nyew, Nilufer Onder, Soner Önder, Zhenlin Wang
# Automated Functional Verification of Application Specific Instruction-set Processors (ID: 7ef0017ceeea58e3a29ae497edde280bfc6b9309)
# Authors: M. Simková, Zdenek Prikryl, Z. Kotásek, Tomás Hruska
# RASTER: Runtime adaptive spatial/temporal error resiliency for embedded processors (ID: 7db3ddb0caa5b1da822243fe9e6825a21042b5dd)
# Authors: Tuo Li, M. Shafique, Jude Angelo Ambrose, Semeen Rehman, J. Henkel, S. Parameswaran
# Implementing microprocessors from simplified descriptions (ID: c59ecae12d00a93970d1331d20387d13cac9fcd7)
# Authors: N. Patil, Derek Chiou
# CSER: HW/SW configurable soft-error resiliency for application specific instruction-set processors (ID: 7c484d04bd64015bd4f5eb33aa15196866b8aa29)
# Authors: Tuo Li, M. Shafique, Semeen Rehman, Swarnalatha Radhakrishnan, R. Ragel, Jude Angelo Ambrose, J. Henkel, S. Parameswaran
# Configurability in IP subystems: Baseband examples (ID: 83c70adf6a3514145fdcd2fbc2efc7d5f9b48b53)
# Authors: P. Thomas, G. Martin, David Heine, D. Moolenaar, James Kim
# Automatic generation of compiler backends (ID: 56ee971e1b7f7786d0da3093247b39825d6110dc)
# Authors: F. Brandner, Viktor Pavlu, A. Krall
# Fine-grained hardware/software methodology for process migration in MPSoCs (ID: bb5d70dec325419c35ee73d26c7a80afaf30c7c4)
# Authors: Tuo Li, Jude Angelo Ambrose, S. Parameswaran
# Processor design using a functional hardware description language (ID: cb5659dd40a591c966d0e4486379b55178c5d462)
# Authors: Stefan Schulze, S. Sawitzki
# ACCGen: An Automatic ArchC Compiler Generator (ID: 64fb62f049b2ada64b0e23c6b78c9342d4240fd8)
# Authors: R. Auler, P. Centoducatte, E. Borin
# Harmless, a hardware architecture description language dedicated to real-time embedded system simulation (ID: b13589b7555c8113367147a3547b61f89bfe8d18)
# Authors: Rola Kassem, M. Briday, Jean-Luc Béchennec, G. Savaton, Y. Trinquet
# Just-in-Time Verification in ADL-based processor design (ID: d7e74e750f7dfded5b5aae0cf149f1e087cd8fbe)
# Authors: Dominik Auras, Andreas Minwegen, Uwe Deidersen
# Reli: Hardware/software Checkpoint and Recovery scheme for embedded processors (ID: 0c0a10ab39744a762b21255db72695d49d69ee39)
# Authors: Tuo Li, R. Ragel, S. Parameswaran
# Automatic generation of functional models for embedded processor extensions (ID: d1eb88cf04f1d56b600a22af64de8c9113455879)
# Authors: F. Sun
# Energy optimization of Application-Specific Instruction-Set Processors by using hardware accelerators in semicustom ICs technology (ID: cfc56197adfcbdd4ad5fee1c72614b5f7de0eaf7)
# Authors: U. Meyer-Bäse, Guillermo Botella Juan, Soumak Mookherjee, Encarnación Castillo, Antonio García
# T&D-Bench—Innovative Combined Support for Education and Research in Computer Architecture and Embedded Systems (ID: 7f16589acb4eeb9045234eceb73a0c54a3b13b8c)
# Authors: S. Soares, F. Wagner
# The Java Virtual Machine in retargetable, high-performance instruction set simulation (ID: 4d4101c5583c4958111c890951038b3a4f9b825e)
# Authors: M. Kaufmann, Matthias Häsing, Thomas B. Preußer, R. Spallek
# Extending Harmless architecture description language for embedded real-time systems validation (ID: b5086836494e080831f275a19a3f29c2170b0042)
# Authors: Jean-Luc Béchennec, M. Briday, Valere Alibert
# Enforcing architectural contracts in high-level synthesis (ID: b667dd29f942660a97e74f0e6452ee412c223a3f)
# Authors: N. Patil, Ankit Bansal, Derek Chiou
# Fast just-in-time translated simulator for ASIP design (ID: dc37bb2b31d609a67bb862b516946191fb86ee75)
# Authors: Zdenek Prikryl, J. Kroustek, Tomás Hruska, D. Kolář
# Speeding-up SIMD instructions dynamic binary translation in embedded processor simulation (ID: 6b135a7d4fb3e2d205956c2f60ffd2695c2363c7)
# Authors: Luc Michel, Nicolas Fournel, F. Pétrot
# Virtual Manycore platforms: Moving towards 100+ processor cores (ID: 5c2a3f2c80a5623da469ea12afe28082d2b5bc88)
# Authors: R. Leupers, L. Eeckhout, G. Martin, F. Schirrmeister, N. Topham, Xiaotao Chen
# Design and Simulation of High Performance Parallel Architectures Using the ISAC Language (ID: 72dd8ed1c8f4489e9df831b3084f6df1f6a55ec7)
# Authors: Zdenek Prikryl, J. Kroustek, Tomás Hruska, D. Kolář, Karel Masarík, A. Husár
# Execution models for processors and instructions (ID: 56e210e9bf17f119542b8752f6a9da457479ee7f)
# Authors: F. Brandner, Viktor Pavlu, A. Krall
# Generated Cycle-Accurate Profiler for C Language (ID: 0723739c1d175fa612f837f31988ef3f77defc95)
# Authors: Zdenek Prikryl, Karel Masarík, Tomás Hruska, A. Husár
# Software Design for Real-Time Measuring and Control System Based on LabView and 1553B (ID: 93268539b415f268cc3da1f4e65bcff359de383c)
# Authors: Xudan Xu, Ping Zhang
# Application of multimode HLS techniques to ASIP synthesis (ID: 86e8520c6ce8ed02b81b1a33c60f31302f5296bc)
# Authors: Nina Engelhardt
# Versatile system-level memory-aware platform description approach for embedded MPSoCs (ID: ea5efcd7486f7b1502832e29466b8165d4c3738e)
# Authors: R. Pyka, F. Klein, P. Marwedel, S. Mamagkakis
# Nios II hardware acceleration of the epsilon quadratic sieve algorithm (ID: b73ba2820f8cd7bc4ca8bb97ac5648dda7edf290)
# Authors: U. Meyer-Bäse, G. Botella, Encarnación Castillo, Antonio García
# Functional Test Generation Using Efficient Property Clustering and Learning Techniques (ID: 29d6e3aa30eb7a21f115f0432a42cb66a351ca30)
# Authors: Mingsong Chen, P. Mishra
# Fast Cycle-Accurate Interpreted Simulation (ID: ba2ce8d20d267db484bcc583e5de78fc8de3c371)
# Authors: Zdenek Prikryl, Karel Masarík, Tomás Hruska, A. Husár
# Ultra low power application specific instruction-set processor design for a cardiac beat detector algorithm (ID: e90e20fc608bd450f94d7a334f67033194e4223f)
# Authors: Y. H. Yassin, P. G. Kjeldsberg, Jos Hulzink, Inaki Romero, Jos Huisken
# TotalProf: a fast and accurate retargetable source code profiler (ID: d2172ca072f3c8609cf56d816446f62c0ca46e09)
# Authors: Lei Gao, Jia Huang, J. Ceng, R. Leupers, G. Ascheid, H. Meyr
# Automatic generation of memory interfaces (ID: 45ede6747d25898b56da76e89cdcfe38f9db9980)
# Authors: D. Kammler, E. M. Witte, A. Chattopadhyay, Bastian Bauwens, G. Ascheid, R. Leupers, H. Meyr
# Functional test generation using design and property decomposition techniques (ID: f19a230f44f701838d1b1d410aa4456ee415e0d2)
# Authors: Heon-Mo Koo, P. Mishra
# Electronic Design Automation: Synthesis, Verification, and Test (ID: 320fb89a2c2df92b066b2972258a95475a236c6f)
# Authors: Laung-Terng Wang, Yao-Wen Chang, Kwang-Ting Cheng
# Language-driven Exploration and Implementation of Partially Re-configurable ASIPs (ID: ab64ad60bd31ad7590f813474bd7c8744288e04b)
# Authors: A. Chattopadhyay, R. Leupers, H. Meyr, G. Ascheid
# Specification-based compaction of directed tests for functional validation of pipelined processors (ID: 1521dd8ebe43ebf218a0a9a62af692859be6bccb)
# Authors: Heon-Mo Koo, P. Mishra
# What is a configurable, extensible processor? (ID: 988a20b3aef26a0dff584fef6903b80ce308e273)
# Authors: G. Martin
# Chapter 2 Modeling and Specification of SoC Designs 2 (ID: 93ced604f5fcc8c5e2a189b3c5ff8bdd81b96db2)
# Authors:
# A Target Platform Description Language for Parallel Code Generation (ID: a084532e4107b63ff205befb06478fcf56341317)
# Authors: Christian Schmitt, Frank Hannig, J&#252;rgen Teich
# Hardware/Software Codesign Across Many Cadence Technologies (ID: c010d9b4ce00bf828ac2a2c92afb0a7af2fcb377)
# Authors: G. Martin, F. Schirrmeister, Yosinori Watanabe
# ParaNut-An Open , Scalable , and Highly Parallel Processor Architecture for FPGA-based Systems (ID: 4168c6c2b610a5ccd1e595771141b04bafa4b4c9)
# Authors: G. Kiefer, Mitchell A. Seider, M. Schaeferling
# MINING AND VERIFICATION OF TEMPORAL EVENTS WITH APPLICATIONS IN COMPUTER MICRO-ARCHITECTURE RESEARCH (ID: 09a91587aa192b982b5ec2bceaa7b70e89115b34)
# Authors: Hui Meen Nyew
# Средства функциональной верификации микропроцессоров (ID: 7a8139da45bada14c2b2dbb8531388cacced49ae)
# Authors: А.С. Камкин, А. М. Коцыняк, С. А. Смолов, А.Д. Татарников, М.М. Чупилко, А. А. Сортов
# Modeling and Specification of SoC Designs (ID: b21f618859204fbbbe29378091dad1012164ea44)
# Authors: Mingsong Chen, Xiaoke Qin, Heon-Mo Koo, P. Mishra
# Ingredients of Adaptability: A Survey of Reconfigurable Processors (ID: 3b3935823247ef968f02b43de5763772519c0354)
# Authors: A. Chattopadhyay
# ADL-Driven Simulator Generation for Energy Dissipation Tracing and Monitoring (ID: 944eaadd97c897d80f042d5cd4ecdf74833901e9)
# Authors: Kwang-Man Ko
# Advanced Methods of Microprocessor Simulation (ID: 1009662a0e7214a49e288972325a7566afaa368c)
# Authors: Zdenek Prikryl
# A HW/SW Checkpoint and Recovery Scheme for Embedded Processors (ID: 8a11af346fcf565158d3e43eb2233149cf5d7be2)
# Authors: Tuo Li, R. Ragel, S. Parameswaran, South Wales
# Open-Source Languages (ID: c7cec5451d07010820318049267560f5d41abf7a)
# Authors: S. Rigo, L. Santos, R. Azevedo, G. Araújo
# Modeling application-specific processors for embedded systems (ID: 4493a747a45de5cf91d2a67054287a23277c35a6)
# Authors: F. Brandner, Viktor Pavlu, A. Krall
# An Energy-oriented Retargetable Simulator for Instruction-Set Architecture (ID: b4e6bec0b0c54b68d093737ba7f436cc59fe5cab)
# Authors: K. So, Kwang-Man Ko
# IP-SOC 2010 TLM 2 . 0 STANDARD INTO ACTION : DESIGNING EFFICIENT PROCESSOR SIMULATOR (ID: edc0d5f5b1209e655e6a3fc5ec342d9b1088005e)
# Authors: L. Fossati
# Automatic C Compiler Generation from Architecture Description Language ISAC (ID: 4f6322139aaf30f473e5ac5cfc99eaf8711a5118)
# Authors: A. Husár, Miloslav Trmac, Jan Hranac, Tomás Hruska, Karel Masarík
# Fast Translated Simulation of ASIPs (ID: 5931911f5a40b6af66d2ba65e778e03c8020ca3b)
# Authors: Zdenek Prikryl, J. Kroustek, Tomás Hruska, D. Kolář
# VYSOKÉ UENÍ TECHNICKÉ V BRN (ID: e321d44330e7726a5102b6b0700e430022b1f7f8)
# Authors: Fakulta Chemická, Ústav Chemie Materiál
# Extending HARMLESS Architecture Description Language for Embedded Real-Time Systems Validation (ID: 40ddcff269ac97bd23d833c6c76f9074031e136d)
# Authors: I. Rennes
# Configurable, Extensible Processor System Simulation (ID: 5e9c0b7bf2c306f64e7311d0c428c475212623a4)
# Authors: G. Martin, Nenad Nedeljkovic, David Heine
# A balanced HW/SW teaching approach for embedded microprocessors (ID: 8f5ddb96c743ff82bf3e0902214e7521c9d07d87)
# Authors: U. M. Baese, G. Botella, Encarnación Castillo, A. G. García
# DSP Instruction Set Simulation (ID: ec82319fa8a52765dbca249a8e112ec6af6c384d)
# Authors: F. Brandner, N. Horspool, A. Krall
# Software Design for Real-Time Measuring and Control System Based on LabView and 1553B (ID: 987ea04fc65f1ce20e1ef61acd118fe4b67a23a2)
# Authors: Xudan Xu, Ping Zhang
# Electronic system-level design and high-level synthesis (ID: 16e499cec223f26442c1bb81d77de51f6469289c)
# Authors: Jianwen Zhu, N. Dutt
# Fine-Grained ASIP Power Gating : Gate-level study of the break-even point for fine-grained power gating (ID: 29649457eb77c140c0563d36aceac1a46f8e21c5)
# Authors: Anja Niedermeier
# Automatic Tool Generation from Structural Processor Descriptions (ID: 48ca26a319eb14d10be5968f4d94f188e49f5b92)
# Authors: F. Brandner
# What is a configurable, extensible processor? (ID: 86e4fb8e279a532404b96c8c698ace44000c2fa4)
# Authors: G. Martin
# Rate limit hit. Retrying in 1 seconds...
# Rate limit hit. Retrying in 2 seconds...
# Rate limit hit. Retrying in 4 seconds...
# Failed to fetch data for 07d465530e0f76d72d2f9da7e12995189218b811 after 3 attempts.
# Rate limit hit. Retrying in 1 seconds...
# Rate limit hit. Retrying in 2 seconds...
# Rate limit hit. Retrying in 4 seconds...
# Failed to fetch data for 031cc53193d5ebeb0ea6eaa9825076ba5dbcfacd after 3 attempts.
# Rate limit hit. Retrying in 1 seconds...
#
# Citing Papers for: Modélisation du logiciel embarqué à différents niveaux d'abstraction en vue de la validation et la synthèse des systèmes monopuces (ID: efd32d2ca54f7e2bf538bcb15fb43df0f0083c5a)
# Authors: A. Bouchhima
# Conception et optimisation de circuits électroniques communicants pour une intégration au format carte bancaire : application à une serrure de vélo à assistance électrique. (Design and optimization of communicating electronic circuits for an integration in a credit card size) (ID: 8e807fe504bfb05b208a67ce8d99eccfe6ce73d2)
# Authors: F. Lahmani
# Méthodologies de conception pour multiprocesseurs sur circuits logiques programmables (ID: 002d740d64f586b8ed2876b86d6ccccda714d6a0)
# Authors: Riad Benmouhoub
# Conception de haut niveau des MPSoCs à partir d'une spécification Simulink : passerelle entre la conception au niveau système et la génération d'architecture (ID: 4337b18174c4de892a237052840157d81166e87d)
# Authors: Y. Atat
# Team Regal Resource management in large scale distributed systems (ID: 0162c0799a37580f10740b2a1067c7fc25ce78de)
# Authors:
# Evaluation des performances pour les systèmes embarqués hétérogènes, multiprocesseur monopuces (ID: 07ad48168ea8632d17e499f4b60fd34195a200e5)
# Authors: Iuliana Beatrice Bacivarov
#
# Citing Papers for: Estimating processor performance of library function (ID: 374a040553279f4923bbfaa4ef6e20d2b0a4b233)
# Authors: A. Ray, W. Jigang, S. Thambipillai
# Compiler-assisted technique for rapid performance estimation of FPGA-based processors (ID: 358e91ed57bdc51d2e2b818e8ac1b0951e27ab60)
# Authors: Y. Aung, S. Lam, T. Srikanthan
# Analysis of Core-Level Scale-Out Efficiency for OpenMP Programs on Multi-core Processors (ID: e9622422b2b53256b73b7472e151aa8a0992d0b9)
# Authors: Sareh Doroodian, Nima Ghaemian, M. Sharifi
# Estimating overheads of OpenMP directives (ID: 612271c5082579dc3cbf70bfc323f20bd10e75dc)
# Authors: Sareh Doroodian, Nima Ghaemian, M. Sharifi
# Performance estimation framework for FPGA-based processors (ID: 14886e08387c663fca49231af88004d4b48a2c44)
# Authors: Y. Aung, S. Lam, T. Srikanthan
# Performance Estimation: IPC (ID: edd40a31bc781927f32231eb827b80457214fa08)
# Authors: A. Ray, Jigang Wu, T. Srikanthan
# Embedded Processor Selection Using FPGA-based Profiling (ID: b00e73e373a2128f2f8cd1332da7e95969caeb1b)
# Authors: Fadi Obeidat, R. Klenke
# Embedded Processor Selection/Performance Estimation using FPGA-based Profiling (ID: 622aa0ea71c9a5346d6a863e4d7be758338837d1)
# Authors: Fadi Obeidat
# Rate limit hit. Retrying in 1 seconds...
#
# Citing Papers for: Simulação compilada para arquiteturas descritivas em ArchC (ID: 47896d2fbe1a78e88bd96eddad61fe249cfd94da)
# Authors: Marcus Bartholomeu, R. Azevedo
# A language for automatic generation of fast instruction-set compiled simulators (ID: fcbefcc52cc1be2ca20527570e6e2f8d3d657c09)
# Authors: J. Metrôlho, C. Couto, Carlos Alberto Silva, A. Tavares
#
# Citing Papers for: Practical techniques for performance estimation of processors (ID: 16fdcbfb152f92e92c5b55791cbc8590606e85cb)
# Authors: A. Ray, T. Srikanthan, W. Jigang
# Framework for Rapid Performance Estimation of Embedded Soft Core Processors (ID: 355ca10f79369470fc92093d2b685c1eea2471ef)
# Authors: Deshya Wijesundera, A. Prakash, T. Srikanthan, A. Ihalage
# Performance Prediction of HPC Applications on Intel Processors (ID: bd337fb6e8ea9608e1bd043499c1a0127a2e8595)
# Authors: C. Rosales, A. Gómez-Iglesias, Si Liu, Feng Chen, Lei Huang, Hang Liu, A. Lamas-Linares, J. Cazes
# Novel low-power ultrasound digital preprocessing architecture for wireless display (ID: e16cbf881b19ab42c2aab3ad7e3291c4398c43dd)
# Authors: P. Levesque, M. Sawan
# Performance Estimation: IPC (ID: edd40a31bc781927f32231eb827b80457214fa08)
# Authors: A. Ray, Jigang Wu, T. Srikanthan
# Embedded Processor Selection Using FPGA-based Profiling (ID: b00e73e373a2128f2f8cd1332da7e95969caeb1b)
# Authors: Fadi Obeidat, R. Klenke
# On the Feasibility and Limitations of Just-in-Time Instruction Set Extension for FPGA-Based Reconfigurable Processors (ID: 062d6a6dd1646e94c410347a756d54756862b04f)
# ...
# Authors: A. Ometov, A. Levina, Pavel Borisenko, R. Mostovoy, Antonino Orsino, Sergey D. Andreev
# Rapid, User-Transparent, and Trustworthy Device Pairing for D2D-Enabled Mobile Crowdsourcing (ID: 34d89c7aef6020409734ef815920afa3dc04f931)
# Authors: Cong Zhao, Shusen Yang, Xinyu Yang, J. Mccann
# A Reputation System to Evaluate Participants for Participatory Sensing (ID: a5630b9da23c2026f24982049fc35e8945574dd9)
# Authors: Mohannad A. Alswailim, H. Hassanein, Mohammad Zulkernine
# Profile Privacy Aware Framework for Static objects Participatory Sensing (ID: 6436cd5ae1d538be573bb0824af4561b2445820a)
# Authors: D. Kalui, Dezheng Zhang
# Trust-Based IoT Participatory Sensing for Hazard Detection and Response (ID: 54f4fa1b27c747a0598f89935d980bfcc3345685)
# Authors: Jia Guo, I. Chen, J. Tsai, H. Al-Hamadi
# Using Logistic Trust for Event Learning and Misbehaviour Detection (ID: ec2f3a668087e73d4caa4279e4a753b7d8755d0a)
# Authors: Saneeha Ahmed, K. Tepe
# Power management techniques in smartphone-based mobility sensing systems: A survey (ID: 31131f180ae0b4f88e17471d417d0c5a6a08827c)
# Authors: R. Pérez-Torres, C. Torres-Huitzil, Hiram Galeana-Zapién
# A hierarchical cloud architecture for integrated mobility, service, and trust management of service-oriented IoT systems (ID: ccc2a3ccdac286cea60ed379e83d840ed517741d)
# Authors: Jia Guo, I. Chen, J. Tsai, H. Al-Hamadi
# A Formal Framework for Modeling Trust and Reputation in Collective Adaptive Systems (ID: 23c31ffe9749d843a8db7be917ea3986d99e99f1)
# Authors: A. Aldini
# DTSRS: A Dynamic Trusted Set based Reputation System for Mobile Participatory Sensing Applications (ID: 663fd39ed03ff60c620b9b2aab92b1172f5f393d)
# Authors: Hayam Mousa, M. Hadhoud, O. Younes, Sonia Ben Mokhtar, L. Brunie
# Design Guidelines on Trust Management for Underwater Wireless Sensor Networks (ID: c0c8bf741391249c9771fa8ab5a1ad7ea1350374)
# Authors: Rong-bo Zhu, A. Boukerche, Libo Long, Qiuling Yang
# Privacy in Mobile Participatory Sensing (ID: a7d8c91ea5171759bc784cb1c0f0e5c8e8b06dae)
# Authors: D. Reinhardt
# Taxonomy of Payment Structures and Economic Incentive Schemes in Internet (ID: 77a73d008de82f6237debabddafe65ed4137847f)
# Authors: B. Gupta, Prachi Gulihar
# A User-Centric Task Allocation Approach in Mobile Crowdsensing (ID: 94382ef9c9fc0f43fec1f47ad4cee501929bf675)
# Authors: Moirangthem Goldie Meitei, Ningrinla Marchang
# Credibility on Crowdsensing Data Acquisition: A Systematic Mapping Study (ID: bda153e989e36c133b2a04b22725fe88d8e1dbb0)
# Authors: M. S. Neto, D. Gomes, J. M. Soares
# IoT Based Blockchain Solution To Endorse Positive Human Behaviour (ID: 292aedb31caa498d1d5e135c1616b346061e733d)
# Authors: Annant Vijay, Kushwaha, Harihara Vinayakaram, Natarajan, Keerthana Jayakumaran, Prachi Gupta, Sahana Krishna, Karki
# Trust-based protocols for secure collaborative routing in wireless mobile networks (ID: 00715a34648df3b559e7d4d4375d3232926abfb4)
# Authors: A. Usman
# An Implementation Roadmap (ID: 3dae790264f4d44b24661bc2b584eea550adbb20)
# Authors: Denis Trček
# Preserving Accuracy and Privacy in Participatory Sensing Systems (ID: b2c4a05c600a47e4b4da6ed39daf3f67ed7b7e57)
# Authors: Mohannad A. Alswailim
# Design of a Shared Parking System with special attention to security aspects (ID: cc350816c2b75b9bfc63d9562b8b5ff68807cdfe)
# Authors: Simon Englert, D. Dmitrienko
# A reputation system resilient against colluding and malicious adversaries in mobile participatory sensing applications (ID: b4cae774c5f232b551014c6520d76a9794b67d2e)
# Authors: Hayam Mousa, Sonia Ben Mokhtar, Omar Hasan, L. Brunie, O. Younes, M. M. Hadhoud
# Design and Veriﬁcation of Trusted Collective Adaptive Systems (ID: 5896a5a9e9576faf568cfeb169c9988ee1da9855)
# Authors: A. Aldini
# Service-Oriented Computing – ICSOC 2016 Workshops (ID: 81770171b691009037762fc0ef95ccb1968048ff)
# Authors: F. Charoy, K. Drira, Hongbing Wang, Qi Yu, Yan Wang, Yuhong Yan, J. Mendling, Mohamed Mohamed, Zhongjie Wang, Sami Bhiri
# Trust Establishment and Management in Adhoc Networks (ID: fe8f806c28823b89c1c9d2dc98d62ad144531660)
# Authors: Saneeha Ahmed
# Entropy-Based Recommendation Trust Model for Machine to Machine Communications (ID: 4485cad45a6e0047feadd3dd471e07b986a4e1de)
# Authors: Saneeha Ahmed, K. Tepe
# Proceedings of the Third Workshop on Blockchain Technologies and its Applications (ID: 2459bbf6fc57439fb41953fa2a1bf65ad077cfc1)
# Authors: P. Agarwal, Sagar Ganiga, S. Saha, A. Mishra, H. Natarajan
# R -manager: Consortium Blockchain-based Vehicle Reputation Management for High-quality Reports in Traffic-oriented Crowdsourcing (ID: 5d0f1a35a9cfba779ad1f9f059276a9b8b202ca5)
# Authors: Enze Yu, Member Ieee Yuwei Xu, Lin Gao, Jie Cao, Y. Yu, L. Xu, J. Gao, Cao
# Rate limit hit. Retrying in 1 seconds...
#
# Citing Papers for: On Robustness of Trust Systems (ID: 26c790ca2f865d5618fa86fc89ec22fe5868541e)
# Authors: Tim Muller, Yang Liu, S. Mauw, Jie Zhang
# A Simulation Software for the Evaluation of Vulnerabilities in Reputation Management Systems (ID: 6b4f56c46b9a6502aefe5d8b71c222202b7f0b67)
# Authors: V. Agate, Alessandra De Paola, G. Re, M. Morana
# Model checking of robustness properties in trust and reputation systems (ID: f383d190ba933f0e4ffef966b145ebb3f920e9f1)
# Authors: Seyed Asgary Ghasempouri, B. T. Ladani
# Modeling trust and reputation systems in hostile environments (ID: 1f9d7215bb71febc0f824aae008b8fff249ad37e)
# Authors: Seyed Asgary Ghasempouri, B. T. Ladani
# The Reputation Lag Attack (ID: 49c512e21035f681b4194b9af639215f49f0b882)
# Authors: Sean Sirur, Tim Muller
# Specification and automatic verification of trust-based multi-agent systems (ID: 25f4032cc50f71722e7cceb8f3a1053d0d1fac9c)
# Authors: Nagat Drawel, Hongyang Qu, J. Bentahar, E. Shakshuki
# A Formal Model for Security Analysis of Trust and Reputation systems (ID: c2676438e8ee4f91a0a2b863f4066da931d5490e)
# Authors: Seyed Asgary Ghasempouri, B. T. Ladani
# Trust It or Not? An Empirical Study of Rating Mechanism and Its Impact on Smartphone Malware Propagation (ID: f9fe658d61c7817d5f6790edba0e79961f6a7195)
# Authors: Wenjuan Li, Lijun Jiang, W. Meng, Lam-for Kwok
# Modeling and Quantitative Verification of Trust Systems Against Malicious Attackers (ID: ce12987b71348571a3bfe4366de7e67c58875008)
# Authors: Amir Jalaly Bidgoly, B. T. Ladani
# A Language for Trust Modelling (ID: 48667254f10fa97434ed13c63b3f2af5209e80fe)
# Authors: Tim Muller, Jie Zhang, Yang Liu
# Benchmarking reputation systems: A quantitative verification approach (ID: 15a12853354bdf4885eceabfa6914b94ec44b0a9)
# Authors: Amir Jalaly Bidgoly, B. T. Ladani
# The Fallacy of Endogenous Discounting of Trust Recommendations (ID: 6680274f8a19e39d732453768b37470ad8cb53a7)
# Authors: Tim Muller, Yang Liu, Jie Zhang
# Using Information Theory to Improve the Robustness of Trust Systems (ID: 0f15176f795e970b52245345f325717de9df7b81)
# Authors: Dongxia Wang, Tim Muller, Athirai Aravazhi Irissappane, Jie Zhang, Yang Liu
# Towards Robust and Effective Trust Management for Security: A Survey (ID: 5c2e2dca97456eefa4da7c0d0546ca5861b961f4)
# Authors: Dongxia Wang, Tim Muller, Yang Liu, Jie Zhang
# Partner Selection Strategy in Open, Dynamic and Sociable Environments (ID: e8325dfd6497b258773626fa0b49ea1d9113c76b)
# Authors: Qin Liang, Wen Gu, Shohei Kato, F. Ren, Guoxin Su, Takayuki Ito, Minjie Zhang
# Properties of Reputation Lag Attack Strategies (ID: 9d2e7eca2e863dee3cebaacb3b9dcefb79fe96d1)
# Authors: Sean Sirur, Tim Muller
# Towards the design of robust incentive mechanisms to address subjectivity and dishonesty problems in agent reporting (ID: d8503dcc650a6291a5526ec01b0bc3d731651875)
# Authors: Yuan Liu
#
# Citing Papers for: Trust Assessment Using Cloud Broker (ID: 64623c9d57d873a8880fe70bc3fb267a8b174da3)
# Authors: P. Pawar, M. Rajarajan, T. Dimitrakos, A. Zisman
# Cloud Broker Recommendation Framework to Provide Trustworthy Cloud Services to the End User (ID: bebacc63184a14bb569c04b55c501a56ab345763)
# Authors: M. Marimuthu, J. Akilandeswari, B. Varasree, Gunupudi RAJESH KUMAR, S. Ramasubbareddy
# Identification of trustworthy cloud services: solution approaches and research directions to build an automated cloud broker (ID: bd92113b93acecab5486bb86320fe61a684bb18c)
# Authors: M. Marimuthu, J. Akilandeswari, P. Chelliah
# Impact of Trust and Reputation Based Brokerage on the CloudAnchor Platform (ID: a5281b62915b1864e66a9f8722a10512cc439923)
# Authors: Bruno Veloso, Benedita Malheiro, J. C. Burguillo, João Gama
# Find my trustworthy fogs: A fuzzy-based trust evaluation framework (ID: af3387c3d458e15f8eaac17da3448440e838bb5c)
# Authors: Fatin Hamadah Rahman, Thien-Wan Au, S. Newaz, W. S. Suhaili, Gyu Myoung Lee
# Revenue Maximization for Dynamic Expansion of Geo-Distributed Cloud Data Centers (ID: 13e10b485d6d111a46812b3915b41644c8c70330)
# Authors: Hou Deng, Liusheng Huang, Hongli Xu, Xiangyang Liu, Pengzhan Wang, Xianjin Fang
# TSLAM: A Trust-enabled Self-Learning Agent Model for Service Matching in the Cloud Market (ID: cea4996aafcf454620bd597c8be120fe64d6264f)
# Authors: Wenjuan Li, Jian Cao, Shiyou Qian, R. Buyya
# Towards Secure Cloud Orchestration for Multi-Cloud Deployments (ID: cfd5b0ae07090273e7a99b4919d3904548fec1cf)
# Authors: Nicolae Paladi, A. Michalas, Hai-Van Dang
# Towards an inter-Cloud architecture in healthcare system (ID: f75f4cb531a6a2ac20e384976cc9aaf926ade92a)
# Authors: Afaf Ouardi, A. Sekkaki, D. Mammass
# CloudAnchor: Agent-Based Brokerage of Federated Cloud Resources (ID: 35cb95c229f112db1e04a212ac745c0b638419f1)
# Authors: Bruno Veloso, Benedita Malheiro, J. C. Burguillo
# Authors: L. Kutvonen
# Time limit exceeded for 0b0feefb1d22078ea6e7ebc01801f7d179ed970c. Stopping collection.
#
# Finished fetching citations for all papers.

# %%
import json
import networkx as nx
from pyvis.network import Network

# File path for stored citation data
DATA_FILE = "IIT_citation_data.json"

# Load citation data from JSON file
def load_data():
    try:
        with open(DATA_FILE, "r") as file:
            return json.load(file)
    except (FileNotFoundError, json.JSONDecodeError):
        print("Error loading data. Ensure citation_data.json exists and is correctly formatted.")
        return {}

# Function to draw the citation graph using PyVis with author details
def draw_graph_pyvis(root_paper_id, citation_edges, citation_dict, author_dict, paper_num):
    net = Network(notebook=True, directed=True, height="800px", width="100%")

    # Enable physics with strong layout for better visibility
    net.barnes_hut(gravity=-5000, central_gravity=0.2, spring_length=500, spring_strength=0.1)

    G = nx.DiGraph()

    # Add nodes with author details
    for paper_id, title in citation_dict.items():
        authors = author_dict.get(paper_id, ["Unknown Author"])
        author_str = ", ".join(authors)

        # Create hover tooltip with author details
        tooltip_text = f"Title: {title}, Authors: {author_str}"

        if paper_id == root_paper_id:
            net.add_node(
                paper_id, 
                label=f"{title}", 
                title=tooltip_text,  # Tooltip on hover
                color="darkred", 
                size=50, 
                font={"size": 30, "bold": True}, 
                physics=False  # Fix the root node in place
            )
        else:
            net.add_node(
                paper_id, 
                label=title, 
                title=tooltip_text,  # Tooltip on hover
                color="pink", 
                size=15, 
                font={"size": 12}
            )
        
        G.add_node(paper_id)

    # Add edges
    for cited_paper_id, citing_paper_id in citation_edges:
        net.add_edge(citing_paper_id, cited_paper_id)
        G.add_edge(citing_paper_id, cited_paper_id)

    # Save and show
    file_name = f"IIT_citation_graph_{paper_num}.html"
    net.show(file_name)
    print(f"Graph saved as {file_name}")

    return G  # Return networkx graph for analysis

# Load stored citation data
citation_data = load_data()

# Generate and visualize graphs
graphs = {}  # Store networkx graphs
for idx, root_paper_id in enumerate(citation_data.keys()):
    citation_edges = citation_data[root_paper_id]["edges"]
    citation_dict = citation_data[root_paper_id]["dict"]
    author_dict = citation_data[root_paper_id].get("authors", {})  # Get authors if available
    graphs[root_paper_id] = draw_graph_pyvis(root_paper_id, citation_edges, citation_dict, author_dict, idx + 1)

print("\nGraphs generated and saved.")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# IIT_citation_graph_1.html
# Graph saved as IIT_citation_graph_1.html
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# IIT_citation_graph_2.html
# Graph saved as IIT_citation_graph_2.html
#
# Graphs generated and saved.

# %%
# Function to compute network measures
def compute_measures(G, paper_num):
    print(f"\n Network Measures for Paper {paper_num}")

    # Compute Diameter
    if nx.is_strongly_connected(G):
        diameter = nx.diameter(G)
        print(f"Graph Diameter: {diameter}")
    else:
        print("Graph is not strongly connected. Diameter cannot be computed.")
        sccs = list(nx.strongly_connected_components(G))
        largest_scc = max(sccs, key=len)
        G_scc = G.subgraph(largest_scc)
        diameter_scc = nx.diameter(G_scc)
        print(f"Diameter of the Largest Strongly Connected Component: {diameter_scc}")

    # Centrality Measures
    degree_centrality = nx.degree_centrality(G)
    closeness_centrality = nx.closeness_centrality(G)
    betweenness_centrality = nx.betweenness_centrality(G)
    eigenvector_centrality = nx.eigenvector_centrality(G, max_iter=1000)
    pagerank = nx.pagerank(G)

    print("\nTop 5 Nodes by Degree Centrality:")
    print(sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:5])

    print("\nTop 5 Nodes by Closeness Centrality:")
    print(sorted(closeness_centrality.items(), key=lambda x: x[1], reverse=True)[:5])

    print("\nTop 5 Nodes by Betweenness Centrality:")
    print(sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)[:5])

    print("\nTop 5 Nodes by Eigenvector Centrality:")
    print(sorted(eigenvector_centrality.items(), key=lambda x: x[1], reverse=True)[:5])

    print("\nTop 5 Nodes by PageRank:")
    print(sorted(pagerank.items(), key=lambda x: x[1], reverse=True)[:5])

    # HITS Algorithm
    hubs, authorities = nx.hits(G)
    print("\nTop 5 Nodes by Hub Score:")
    print(sorted(hubs.items(), key=lambda x: x[1], reverse=True)[:5])

    print("\nTop 5 Nodes by Authority Score:")
    print(sorted(authorities.items(), key=lambda x: x[1], reverse=True)[:5])

    # Clustering Coefficients
    global_clustering = nx.average_clustering(G)
    local_clustering = nx.clustering(G)

    print(f"\nGlobal Clustering Coefficient: {global_clustering}")

    print("\nTop 5 Nodes by Local Clustering Coefficient:")
    print(sorted(local_clustering.items(), key=lambda x: x[1], reverse=True)[:5])

    # Connected Components
    if nx.is_directed(G):
        weakly_connected_components = list(nx.weakly_connected_components(G))
        print(f"\nNumber of Weakly Connected Components: {len(weakly_connected_components)}")
    else:
        connected_components = list(nx.connected_components(G))
        print(f"\nNumber of Connected Components: {len(connected_components)}")

# Compute network measures for each graph
for idx, root_paper_id in enumerate(root_paper_ids):
    compute_measures(graphs[root_paper_id], idx + 1)
# Out:
#  Network Measures for Paper 1
# Graph is not strongly connected. Diameter cannot be computed.
# Diameter of the Largest Strongly Connected Component: 0
#
# Top 5 Nodes by Degree Centrality:
# [('9e4f70e357319cdaab1af7ba8251e98dc9ed321b', 0.2948328267477204), ('bdec376a708b925d235aefcdd748f5c8dca8bc88', 0.22188449848024316), ('c3935b75b1f747864a07cc2a99b0b8fdcb34c26a', 0.18541033434650456), ('92e247b6c18ef5d3c539c281fcf33b27388bb854', 0.0790273556231003), ('36906392fb7c4ea483c5abdfcbd6d76663e01bb6', 0.060790273556231005)]
#
# Top 5 Nodes by Closeness Centrality:
# [('6d5986ef3e16b1fb5efe8da4a0b56c51187334d1', 0.014963759644610709), ('84664b3e75b9e661c08307067b34d9679d14daed', 0.01094224924012158), ('8d68b7f29acdcc39e5fc08a57ce75e47693cde0d', 0.01094224924012158), ('b13589b7555c8113367147a3547b61f89bfe8d18', 0.010855405992184108), ('4f6322139aaf30f473e5ac5cfc99eaf8711a5118', 0.009498480243161094)]
#
# Top 5 Nodes by Betweenness Centrality:
# [('9e4f70e357319cdaab1af7ba8251e98dc9ed321b', 0.002914411742901624), ('b13589b7555c8113367147a3547b61f89bfe8d18', 0.0006440432945362889), ('bdec376a708b925d235aefcdd748f5c8dca8bc88', 0.0006255096745496331), ('45ede6747d25898b56da76e89cdcfe38f9db9980', 0.0002641040848098451), ('92e247b6c18ef5d3c539c281fcf33b27388bb854', 0.00022240343983986953)]
