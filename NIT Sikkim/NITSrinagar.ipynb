# %%
import requests
import time
import json
import os

# File path to store citation data
DATA_FILE = "NIT_citation_data.json"

# Function to fetch citation data for a given paper ID with retries
def fetch_citations(paper_id, max_retries=3):
    url = f"https://api.semanticscholar.org/graph/v1/paper/{paper_id}?fields=title,authors,citations.paperId,citations.title,citations.authors"

    for attempt in range(max_retries):
        try:
            response = requests.get(url, timeout=10)  # Set timeout to avoid hanging requests

            if response.status_code == 200:
                return response.json()
            elif response.status_code == 429:  # Rate limit exceeded
                wait_time = 2 ** attempt  # Exponential backoff
                print(f"Rate limit hit. Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
            else:
                print(f"Error {response.status_code} for {paper_id}: {response.text}")
                return None

        except requests.exceptions.RequestException as e:
            print(f"Request failed (Attempt {attempt+1}/{max_retries}): {e}")
            time.sleep(2)  # Small delay before retrying

    print(f"Failed to fetch data for {paper_id} after {max_retries} attempts.")
    return None

# Load existing data if available
def load_existing_data():
    if os.path.exists(DATA_FILE):
        with open(DATA_FILE, "r") as file:
            try:
                return json.load(file)
            except json.JSONDecodeError:
                print("Error loading existing data. Starting fresh.")
                return {}
    return {}

# Save data to a file
def save_data(data):
    with open(DATA_FILE, "w") as file:
        json.dump(data, file, indent=4)

# Root paper IDs
root_paper_ids = [
    "559bcef033955ecb32aca43649b44fceb31c59aa",  # Paper 1
    "49af9b46020639c7b9f0a59c77b2e1b3bd53157c"   # Paper 2
]

# Load previously saved data
citation_data = load_existing_data()

# Fetch citation data for each paper if not already saved
for root_paper_id in root_paper_ids:
    if root_paper_id in citation_data:
        print(f"Data for {root_paper_id} already exists. Skipping fetch.")
        continue

    citation_dict = {}
    author_dict = {}  
    citation_edges = []
    id_arr = [root_paper_id]  # Queue for BFS-like processing

    # Set a time limit (3 minutes = 180 seconds)
    start_time = time.time()

    while id_arr:
        elapsed_time = time.time() - start_time
        if elapsed_time > 180:  
            print(f"Time limit exceeded for {root_paper_id}. Stopping collection.")
            break
        
        paper_id = id_arr.pop(0)  
        data = fetch_citations(paper_id)

        if data:
            paper_title = data.get("title", "Unknown Paper")
            authors = [author.get("name", "Unknown Author") for author in data.get("authors", [])]

            citation_dict[paper_id] = paper_title  
            author_dict[paper_id] = authors  # Store authors

            print(f"\nCiting Papers for: {paper_title} (ID: {paper_id})")
            print(f"Authors: {', '.join(authors)}")

            for citation in data.get("citations", []):
                cited_paper_id = citation.get("paperId")
                cited_paper_title = citation.get("title", "Unknown Title")
                cited_authors = [author.get("name", "Unknown Author") for author in citation.get("authors", [])]

                if cited_paper_id and cited_paper_title:
                    if cited_paper_id not in citation_dict:
                        citation_dict[cited_paper_id] = cited_paper_title
                        author_dict[cited_paper_id] = cited_authors
                        id_arr.append(cited_paper_id)  

                    citation_edges.append([cited_paper_id, paper_id])  

                    print(f"{cited_paper_title} (ID: {cited_paper_id})")
                    print(f"Authors: {', '.join(cited_authors)}")

        time.sleep(5)

    citation_data[root_paper_id] = {
        "dict": citation_dict, 
        "authors": author_dict, 
        "edges": citation_edges
    }

    save_data(citation_data)

print("\nFinished fetching citations for all papers.")
# Out:
# Citing Papers for: Applicability of Blockchain smart contracts in securing Internet and IoT: A systematic literature review (ID: 559bcef033955ecb32aca43649b44fceb31c59aa)
# Authors: Auqib Hamid Lone, R. N. Mir
# Improving IoT Management with Blockchain: Smart Home Access Control (ID: 09d8a7cbb0d25f651c6d05f52eeb9dec430b98d8)
# Authors: Andrej Gono, Ivo Pisařovic, Martin Zejda, Jaromír Landa, David Prochazka
# Distributed Databases for Computer Applications: Study and Selection of Distributed Ledger Technologies (ID: f8df957983453554ac630db47d512e2f7ad47225)
# Authors: Carlo Kleber da Silva Rodrigues
# Leveraging the usage of blockchain toward trust-dominated manufacturing systems (ID: fa22cc67208cefb1ac3d92e7a67f1e25a202c7b1)
# Authors: Philip Samaha, Fadi El Kalach, R. Harik
# Exploring IoT and Blockchain: A Comprehensive Survey on Security, Integration Strategies, Applications and Future Research Directions (ID: faf3b2b9c5ecd071f29a1ccd25bd294eaf7f140c)
# Authors: Muath A. Obaidat, Majdi Rawashdeh, Mohammad Alja’afreh, Meryem Abouali, Kutub Thakur, Ali Karime
# Analysing critical success factor of smart contract in construction industry with DANP approach (ID: 3eca44f10a9e667636f94df832f74c1e16c3802c)
# Authors: Hooman Rasti, A. Feili, Shahryar Sorooshian
# A survey on security issues in IoT operating systems (ID: 511ae9c052e0fb47e92d2b7a5bdd793dc84cc34c)
# Authors: Panjun Sun, Yi Wan, Zong-Bing Wu, Zhaoxi Fang
# Access Control Verification in Smart Contracts Using Colored Petri Nets (ID: bf8321e237ad1b2d8f257d05ea671061c74526ff)
# Authors: Issam Al-Azzoni, S. Iqbal
# FVF-BIoT: a formal verification framework for blockchain-based IoT authentication (ID: 42068e359bd38771b477b484b5f62b59144bf822)
# Authors: Jiaqi Yin, Yuan Fei
# Towards a Standard Framework for Integrating Blockchain with the Internet of Things (ID: 4fcdba4b4af6031a6d7791f540287911b4d396b2)
# Authors: Sadegh Sohani, Maliheh Shahryari, Mohammad Allahbakhsh, Haleh Amintoosi
# Unlocking the potential of blockchain technology in enhancing the fisheries supply chain: an exploration of critical adoption barriers in China (ID: 1308f67535e4c1d3394c36dfeaa9c78f42e1490e)
# Authors: Ubair Nisar, Zhixin Zhang, Bronwyn P. Wood, Shadab Ahmad, Ehsan Ellahi, Syed Ijaz Ul Haq, Mohamad Alnafissa, Elsayed Fathi Abd_Allah
# A Lightweight Blockchain Scheme for Secure Data Communication in Internet of Things-enabled Wireless Sensor Network (ID: 2e3d6a20354cb9a98bce9639b1525ccaa740ac95)
# Authors: Lavina Balraj, A.Prasanth, K. Sowndarya, T.Kuntavai
# A Smart-Contract-Based Policy-Domain Access Control Framework for Distributed Industrial IoT (ID: 11facb5f4cb932260686959aacad26c8d159d1c8)
# Authors: Song Luo, Tan Hu, Nian Han, Yuhua Qian
# Privacy as a Lifestyle: Empowering assistive technologies for people with disabilities, challenges and future directions (ID: a8ebb7283a5f09ad7ad0002dc185a15251151b06)
# Authors: Adib Habbal, Hassen Hamouda, Abdullah M. Alnajim, Sheroz Khan, M. F. Alrifaie
# Exploring the integration of edge computing and blockchain IoT: Principles, architectures, security, and applications (ID: b120df351458aa013a8b7f9436ea80367dd182f4)
# Authors: Tri Nguyen, Huong Nguyen, Tuan Anh Nguyen Gia
# MSLShard: An efficient sharding-based trust management framework for blockchain-empowered IoT access control (ID: f911fc7d65482c6a07b87465330148925f1d0b19)
# Authors: Jin Tian, Junfeng Tian, Ruizhong Du
# A Systematic Review using Blockchain Technology for IOT-Based Health Care Security (ID: a076be04a113d350ef18e4d2b5786db472f42e7c)
# Authors: Kedar Nath Singh, Arvind Kumar Upadhyay
# Community Healthcare: Safety, Privacy, and Usability of Smart Health Home Technologies (ID: 8ba4783a4f83d10bdaffb1ce6215185920ec032e)
# Authors: Tianhong Cai, Xiang Zhang, Yinglun Li, Stuart McDonald, Vladimir Brusić
# Blockchain-based secure dining: Enhancing safety, transparency, and traceability in food consumption environment (ID: 6c0fab66fc3b870cbb2de7d8cd3f7821b6acd904)
# Authors: Sachin Yele, Ratnesh Litoriya
# TOWARDS STANDARDIZED REGULATIONS FOR BLOCK CHAIN SMART CONTRACTS: INSIGHTS FROM DELPHI AND SWARA ANALYSIS (ID: 8057573b1d411888bf597014422f7b62530a5ce0)
# Authors: Shahin Heidari, Shannon Hashemi, Mohammad-Soroush Khorsand, Alireza Daneshfar, Seyedalireza Jazayerifar
# Revolutionizing Digital Banking: Harnessing Blockchain Smart Contracts for Enhanced Security and Efficiency (ID: 79c0fd7f0e15f4ba5a837f84256611824726098f)
# Authors: Kuldeep Singh, Premalatha K P, Seema Benakatti, Vasudha Srivatsa
# Monetization of Industrial IoT services using Blockchain and smart contract (ID: ca4fd229e9ae99cb49c5dcdc11721efd1ff7f4bc)
# Authors: R. Kilani, A. Zouinkhi, M. Abdelkrim
# Distributed ledger technologies for authentication and access control in networking applications: A comprehensive survey (ID: 43657149d1a5371772d85599b9557fadf1b139ef)
# Authors: Fariba Ghaffari, E. Bertin, Noel Crespi, Julien Hatin
# Blockchain Enabled Real Estate Property Transactions using NFT: An Approach (ID: 7c62a373e4b7b4b5c49ba58ff15a0d775b4b922a)
# Authors: Vivekrabinson K, Bharath Singh J, Rajesh Kumar S, Vijay M, Vijayakumar D, Shanmuga Raja B
# Blockchain Smart Contracts Suitability for Safeguarding the Internet of Things (ID: a285792953d7b89f5682696741c59887866f1256)
# Authors: Deepika Khichi, Ajay Kumar Sharma, Mayank Patel
# An assessment of blockchain academia and news developments: a bibliometric and text-mining analysis (ID: 37e6b75269ad067402f54929d917debe704f1bfb)
# Authors: Chien-wen Shen, Phung Phi Tran
# Cryptocurrency and digital currency based on blockchain-enabled IoT: a bibliometric literature review (ID: 3dddc9ab30ae43f976030f28024aedcd1e52c9ca)
# Authors: Yangjing Zhou, Ahmed Najat Ahmed
# Fog Computing with Optimized Block Chain Technique for IoT Based Data Security (ID: 99dd9dcd310c9f861b8dee131d744b12db69e9b5)
# Authors: Dhanya G. S Research Scholar, S. M. Celestin
# IoTBChain: Adopting Blockchain Technology to Increase PLC Resilience in an IoT Environment (ID: f42028a11520e662f567b017402cda94ac45d6ab)
# Authors: Philipp Schmid, Alisa Schaffhäuser, Rasha Kashef
# A Systematic Literature Review on Blockchain Technology in Software Engineering (ID: 1446e3ee52c1e665b89dd1ab41df19acdec507e8)
# Authors: Dzhillan Dzhalila, D. Siahaan, Reza Fauzan, Raka Asyrofi, Muhammad Ihsan Karimi
# A Blockchain-Centric IoT Architecture for Effective Smart Contract-Based Management of IoT Data Communications (ID: 96fb4328b8ccb29c0b1f954c0968e4cb22c3a638)
# Authors: Abdulsalam S. Albulayhi, Ibrahim S. Alsukayti
# Hyper contour cryptography with master Birch‐Brown Paruvala‐SLSTM model for enhanced healthcare security (ID: ede6b17c46fb63ceddfb9c40eb8fe8a54e96a75d)
# Authors: P. Angelin, S. W. Franklin
# Survivability of industrial internet of things using machine learning and smart contracts (ID: 036e45e39b49cba8f644b5a7e6be2ccf5455ef8b)
# Authors: Ishaani Priyadarshini, Raghvendra Kumar, A. Alkhayyat, Rohit Sharma, Kusum Yadav, Lulwah M. Alkwai, Sachin Kumar
# PPFchain: A novel framework privacy-preserving blockchain-based federated learning method for sensor networks (ID: 9fdc331483a85529b10e52ee652406cd58ac25ae)
# Authors: Bora Buğra Sezer, Hasret Turkmen, U. Nuriyev
# Collaborative Smart Contracts (CoSC): example of real estate purchase and sale(s) (ID: 8d7e9b3af9144e97bb2885c22ae422ecd75ca261)
# Authors: Tunahan Timucin, Serdar Biroğul
# Barriers to blockchain technology adoption in supply chains: the case of India (ID: 169b15e5eaa1cb2b5b3ab1874fdd2cd38f2f1ea2)
# Authors: Shahbaz Khan, A. Haleem, Zafar Husain, D. Samson, R. D. Pathak
# A Blockchain-Based Cross-Domain and Autonomous Access Control Scheme for Internet of Things (ID: c16d07c0a8898c548961c0be1e14029d86df0d8c)
# Authors: Xiaohan Hao, Wei Ren, Yang-yang Fei, Tianqing Zhu, K. Choo
# Access management of IoT devices using access control mechanism and decentralized authentication: A review (ID: 1abc213403b16ca5cb4851ab3e1e95baafc68710)
# Authors: Inderpal Singh, Balraj Singh
# Blockchain-enabled access control to prevent cyber attacks in IoT: Systematic literature review (ID: 640c8d79663ce5a751b8cdb030e69315e4609ef0)
# Authors: Rinki Singh, Deepika Kukreja, Devender Kumar Sharma
# Blockchain Enabled Architecture with Selective Consensus Mechanisms for IoT Based Saffron-Agri Value Chain (ID: 38f6210acef46a736ccb119d3daee12c2b5e6e47)
# Authors: Jahangeer Ali, S. Sofi
# IoT with Multimedia Investigation: A Secure Process of Digital Forensics Chain-of-Custody using Blockchain Hyperledger Sawtooth (ID: 70bdbb1985cd68b4e1253886168e54957cb11377)
# Authors: A. Khan, A. Shaikh, Asif Ali Laghari
# Securing the Internet of Things via Blockchain-Aided Smart Contracts (ID: 773fbfaa49d82921dd5c18ed28513d16c76729ca)
# Authors: S. M. Zanjani, Hossein Shahinzadeh, Jalal Moradi, Zohreh Rezaei, Bahareh Kaviani-Baghbaderani, Sudeep Tanwar
# Decision-making factors in the adoption of smart contracts in Brazilian companies (ID: 1fbb3b5dcb033c0e482b2523acfd239e27d6ef62)
# Authors: Alan Moreira Lopes, Jurandir Peinado, F. Vianna, Francis Kanashiro Meneghetti
# Blockchain and 6G-Enabled IoT (ID: bbcd2346008c1d037a4b80cffd2c9c58c5ffd0de)
# Fusion of Blockchain, IoT and Artificial Intelligence - A Survey (ID: 7ba631484c71ecce231021b41c1fe78a35b129c2)
# Authors: Srinivas Koppu, Kumar K, Siva Rama KRISHNAN SOMAYAJI, Iyapparaja Meenakshisundaram, Weizheng Wang, Chunhua Su
# Security Improvement Technique for Distributed Control System (DCS) and Supervisory Control‐Data Acquisition (SCADA) Using Blockchain at Dark Web Platform (ID: 27f0cd019e346c7414d396f61ad3f994ce63f927)
# Authors: A. Rajawat, Romil Rawat, Kanishk Barhanpurkar
# Unified Authentication and Access Control for Future Mobile Communication-Based Lightweight IoT Systems Using Blockchain (ID: 9c637957b17c76d17768a1b3641d4a3e94e2a588)
# Authors: Shubham Joshi, S. Stalin, P. Shukla, P. Shukla, Ruby Bhatt, Rajan Singh Bhadoria, B. Tiwari
# Trustful data trading through monetizing IoT data using BlockChain based review system (ID: 0b26ee2aa4e77598f200f75c0b6ec9ef3c12b23a)
# Authors: Zain Abubaker, Asad Ullah Khan, Ahmad S. Almogren, Shahid Abbas, Atia Javaid, A. Radwan, Nadeem Javaid
# On the impact of smart contracts on auditing (ID: 773430511053621a88eed27c533abcc369058e26)
# Authors: J. Andrés, Pedro Lorca
# A Secure Access Scheme for Internet of Things Devices Based on Blockchain (ID: 92c9af9242931ee810bf04d584044e6fad4a8e40)
# Authors: Wenzheng Li, JiYue Ying
# A survey: Making “Smart Contracts” really smart (ID: 0d138db654e9a661709013814643d443886bd74d)
# Authors: Tunahan Timucin, Serdar Biroğul
# Security enhancement technologies for smart contracts in the blockchain: A survey (ID: 3212d7606722a43fd1ea7c4334fabdad88cd9637)
# Authors: Yajing Wang, Jingsha He, Nafei Zhu, Yuzi Yi, Qingqing Zhang, Hongyu Song, Ruixin Xue
# Technical Sustainability of Cloud-Based Blockchain Integrated with Machine Learning for Supply Chain Management (ID: 834f0c64491c23b9e4259ac85f4e092da8113a5a)
# Authors: Simon Wong, John-Kun-Woon Yeung, Yui-yip Lau, J. So
# A study of application platform for smart contract visualization based blockchain (ID: 15a3ed0f3cff4bc79ff6da9803563a7e005fc882)
# Authors: Soonhyeong Jeong, Byeongtae Ahn
# Contact tracing apps for the COVID-19 pandemic: a systematic literature review of challenges and future directions for neo-liberal societies (ID: aa76e3e0f5a2d4f3f03815171bb62e5de787a554)
# Authors: A. Akinbi, M. Forshaw, Victoria Blinkhorn
# A systematic literature mapping on secure identity management using blockchain technology (ID: d3569820eb46ed2d219f1c35f9eda8661383757b)
# Authors: Tripti Rathee, Parvinder Singh
# Acceptance Rate Prediction of Blockchain in Automotive Supply Chain Management With a Bayesian Distributive Gradient Integrated BiLSTM (ID: 9058952041e7f0b4143b8700be09b6b0cbf0cccc)
# Authors: Ahlaam Albuloushi, A. Alzubi, Tolga Öz
# Blockchain Based Secured Load Balanced Task Scheduling Approach for Fitness Service (ID: ee71dd894d4efb4af9dbe6018cf201ff93377f11)
# Authors: Muhammad Ibrahim, Faisal Jamil, Yunjung Lee, Dohyeun Kim
# Blockchain-based Federated Learning for Securing Internet of Things: A Comprehensive Survey (ID: b24d7a0afb252fdf8451de53504c03e6f42c627d)
# Authors: Wael Issa
# INDUSTRY 4.0, SUSTAINABILITY AND INNOVATION AT THE CROSSROAD: A REVIEW ANALISYS (ID: 52a282282e8a0c0677359e16d317ad2af58b625d)
# Authors: Florin Pucheanu
# IoT and Blockchain combined: for decentralized security (ID: 292f92b9174f083e7ccdc05b9a3fe7890a55a52a)
# Authors: Younés Abbassi, H. Benlahmar
# Rate limit hit. Retrying in 1 seconds...
#
# Citing Papers for: Improving IoT Management with Blockchain: Smart Home Access Control (ID: 09d8a7cbb0d25f651c6d05f52eeb9dec430b98d8)
# Authors: Andrej Gono, Ivo Pisařovic, Martin Zejda, Jaromír Landa, David Prochazka
#
# Citing Papers for: Distributed Databases for Computer Applications: Study and Selection of Distributed Ledger Technologies (ID: f8df957983453554ac630db47d512e2f7ad47225)
# Authors: Carlo Kleber da Silva Rodrigues
#
# Citing Papers for: Leveraging the usage of blockchain toward trust-dominated manufacturing systems (ID: fa22cc67208cefb1ac3d92e7a67f1e25a202c7b1)
# Authors: Philip Samaha, Fadi El Kalach, R. Harik
# Blockchain-based digital product passport: design principles and demonstration (ID: d8ce1817b915ac7fc7a8e57ebf6ce47e79f374c9)
# Authors: Hugo Abreu, Vasco Pereira, João Barata
# ParaBFT: An Efficient Parallel Asynchronous BFT Agreement (ID: 9c173f82230a5cdee7f5a95954f98dc90b689fc0)
# Authors: Yu Lan, Hui Huang, Qingming He, Caixia Wu, Shuaike Wu, Xiangzeng Kong
#
# Citing Papers for: Exploring IoT and Blockchain: A Comprehensive Survey on Security, Integration Strategies, Applications and Future Research Directions (ID: faf3b2b9c5ecd071f29a1ccd25bd294eaf7f140c)
# Authors: Muath A. Obaidat, Majdi Rawashdeh, Mohammad Alja’afreh, Meryem Abouali, Kutub Thakur, Ali Karime
#
# Citing Papers for: Analysing critical success factor of smart contract in construction industry with DANP approach (ID: 3eca44f10a9e667636f94df832f74c1e16c3802c)
# Authors: Hooman Rasti, A. Feili, Shahryar Sorooshian
#
# Citing Papers for: A survey on security issues in IoT operating systems (ID: 511ae9c052e0fb47e92d2b7a5bdd793dc84cc34c)
# Authors: Panjun Sun, Yi Wan, Zong-Bing Wu, Zhaoxi Fang
# Current research on Internet of Things (IoT) security protocols: A survey (ID: 0a22e93aab234e0f68e82293c1a894073b2fa3ba)
# Authors: Raghavendra Mishra, Ankita Mishra
# A Survey on Physical Layer Security for 5G/6G Communications over Different Fading Channels: Approaches, Challenges, and Future Directions (ID: 2598f2f6d1c8968a90de1b4b7c1bf03d1c783e1f)
# Authors: Parmila Devi, M. R. Bharti, Dikshant Gautam
# Rate limit hit. Retrying in 1 seconds...
#
# Citing Papers for: Access Control Verification in Smart Contracts Using Colored Petri Nets (ID: bf8321e237ad1b2d8f257d05ea671061c74526ff)
# Authors: Issam Al-Azzoni, S. Iqbal
# Rate limit hit. Retrying in 1 seconds...
#
# Citing Papers for: FVF-BIoT: a formal verification framework for blockchain-based IoT authentication (ID: 42068e359bd38771b477b484b5f62b59144bf822)
# Authors: Jiaqi Yin, Yuan Fei
#
# Citing Papers for: Towards a Standard Framework for Integrating Blockchain with the Internet of Things (ID: 4fcdba4b4af6031a6d7791f540287911b4d396b2)
# Authors: Sadegh Sohani, Maliheh Shahryari, Mohammad Allahbakhsh, Haleh Amintoosi
# Review on Open-Source IoT and Edge-Compatible Devices for Health Monitoring Applications (ID: 36fc9576c90ef2a3a60074980cba509cbaee0721)
# Authors: Mamta Kumari, Mahendra Gaikwad, Salim A. Chavan
# Integrating Blockchain and Edge Computing: A Systematic Analysis of Security, Efficiency, and Scalability (ID: e572039d7a3f4b46901d1838c8bbf69afe6d3992)
# Authors: Youness Bentayeb, Kenza Chaoui, Hassan Badir
# Unlocking a Promising Future: Integrating Blockchain Technology and FL-IoT in the Journey to 6G (ID: ccc3daf0653743b871b7e5ea01acf56b1932ce25)
# Authors: Fatemah H. Alghamedy, Nahla El-Haggar, Albandari Alsumayt, Zeyad M. Alfawaer, Majid Alshammari, L. Amouri, Sumayh S. Aljameel, Sarah Albassam
#
# Citing Papers for: MSLShard: An efficient sharding-based trust management framework for blockchain-empowered IoT access control (ID: f911fc7d65482c6a07b87465330148925f1d0b19)
# Authors: Jin Tian, Junfeng Tian, Ruizhong Du
# A Comprehensive Survey on the Requirements, Applications, and Future Challenges for Access Control Models in IoT: The State of the Art (ID: f05e1f3a8ed801d255aa1f50dbd42485718560af)
# Authors: Mohammad Shamim Ahsan, Al-Sakib Khan Pathan
# Variance‐driven security optimisation in industrial IoT sensors (ID: f9300bffd7c4655afaaed707fa05ed849b8c66cc)
# Authors: Hardik Gupta, Sunil K. Singh, Sudhakar Kumar, Karan Sharma, Hardeep Saini, B. Gupta, Varsha Arya, Kwok Tai Chui
# StarCross: Redactable blockchain-based secure and lightweight data sharing framework for satellite-based IoT (ID: f89db4927356922c7e5be18bed0f5e2bbf237a2e)
# Authors: Rui Du, Tianyang Chen, Jin Tian, Tao Shang
# Blockchain for Secure Access Control in the Internet of Things: A Review and Comparative Analysis (ID: f1a43ba2e0c1808b0be037dfede20863624675c6)
# Authors: Maroua Akkal, Sarra Cherbal, Boubakeur Annane, Hicham Lakhlef
# A blockchain-based secure framework for data management (ID: 3220884bbed81b6ba7fdffa30e091ebbf50b8d96)
# Authors: O. Zorlu, Adnan Ozsoy
# Anomaly Detection in Blockchain Networks Using Unsupervised Learning: A Survey (ID: 718cc02268bf66977994cb95779637cde29187a4)
# Authors: Christos Cholevas, Eftychia Angeli, Zacharoula Sereti, Emmanouil Mavrikos, G. Tsekouras
# TIoT: A Trust by Design Architecture for Secure and Private Internet of Things (IoT) (ID: f08be8038fd81b7ace9db03afa3562c72fda466d)
# Authors: H. Alsheakh, Tareq Nasser Mahdi, Mustafa S. Kadhm, Abeer Al Shammari, Fatimah I. Abdulsahib, Hazeem B Taher, Waleed Algriree, Marwa Q. Alobaidi, Hayder Dhafer Mohammed
#
# Citing Papers for: A Systematic Review using Blockchain Technology for IOT-Based Health Care Security (ID: a076be04a113d350ef18e4d2b5786db472f42e7c)
# Authors: Kedar Nath Singh, Arvind Kumar Upadhyay
#
# Citing Papers for: Community Healthcare: Safety, Privacy, and Usability of Smart Health Home Technologies (ID: 8ba4783a4f83d10bdaffb1ce6215185920ec032e)
# Authors: Tianhong Cai, Xiang Zhang, Yinglun Li, Stuart McDonald, Vladimir Brusić
# Rate limit hit. Retrying in 1 seconds...
# Rate limit hit. Retrying in 2 seconds...
#
# Citing Papers for: Monetization of Industrial IoT services using Blockchain and smart contract (ID: ca4fd229e9ae99cb49c5dcdc11721efd1ff7f4bc)
# Authors: R. Kilani, A. Zouinkhi, M. Abdelkrim
#
# Citing Papers for: Distributed ledger technologies for authentication and access control in networking applications: A comprehensive survey (ID: 43657149d1a5371772d85599b9557fadf1b139ef)
# Authors: Fariba Ghaffari, E. Bertin, Noel Crespi, Julien Hatin
# DBDAA: Dual blockchain and decentralized identifiers assisted anonymous authentication for building IoT (ID: 91008bdfc6eaeb34e6ba991bd0632c5e27bf5aa7)
# Authors: Xiaohua Wu, Zheng Luo, Jun Cheng, Puyan Wang
# Web3-Powered Service Provisioning in Cellular Networks using NFT and Self-Sovereign Identity (ID: 2bc4285afc2a07b5a8dbb18c2985607579596ba8)
# Authors: Nischal Aryal, Fariba Ghaffari, E. Bertin, Noel Crespi
# A Blockchain-based approach for Service Level Agreement Management in Cellular Network (ID: e22b09e4350e45527c1c532de5c2bc1d367f3954)
# Authors: Nischal Aryal, Fariba Ghaffari, E. Bertin, Noel Crespi
# Mobile robot localization: Current challenges and future prospective (ID: 15bb2f8fc51a0f1051c9671e4263baaa95e243b1)
# Authors: Inam Ullah, Deepak Adhikari, Habib Khan, M. S. Anwar, Shabir Ahmad, Xiaoshan Bai
# Performance, privacy, and security issues of TCP/IP at the application layer: A comprehensive survey (ID: 02f76cff8efec5cea2b526fb9511092627a162f1)
# Authors: Timothy Murkomen
# Security challenges in cloud computing: A comprehensive analysis (ID: 9ce8f72b6bf47c39abe8e07990e7dfed2173c17e)
# Authors: Janet Julia Ang'udi
#
# Citing Papers for: Blockchain Enabled Real Estate Property Transactions using NFT: An Approach (ID: 7c62a373e4b7b4b5c49ba58ff15a0d775b4b922a)
# Authors: Vivekrabinson K, Bharath Singh J, Rajesh Kumar S, Vijay M, Vijayakumar D, Shanmuga Raja B
# Time limit exceeded for 559bcef033955ecb32aca43649b44fceb31c59aa. Stopping collection.
# Data for 49af9b46020639c7b9f0a59c77b2e1b3bd53157c already exists. Skipping fetch.
#
# Finished fetching citations for all papers.

# %%
import json
import networkx as nx
from pyvis.network import Network

# File path for stored citation data
DATA_FILE = "NIT_citation_data.json"

# Load citation data from JSON file
def load_data():
    try:
        with open(DATA_FILE, "r") as file:
            return json.load(file)
    except (FileNotFoundError, json.JSONDecodeError):
        print("Error loading data. Ensure citation_data.json exists and is correctly formatted.")
        return {}

# Function to draw the citation graph using PyVis with author details
def draw_graph_pyvis(root_paper_id, citation_edges, citation_dict, author_dict, paper_num):
    net = Network(notebook=True, directed=True, height="800px", width="100%")

    # Enable physics with strong layout for better visibility
    net.barnes_hut(gravity=-5000, central_gravity=0.2, spring_length=500, spring_strength=0.1)

    G = nx.DiGraph()

    # Add nodes with author details
    for paper_id, title in citation_dict.items():
        authors = author_dict.get(paper_id, ["Unknown Author"])
        author_str = ", ".join(authors)

        # Create hover tooltip with author details
        tooltip_text = f"Title: {title}, Authors: {author_str}"

        if paper_id == root_paper_id:
            net.add_node(
                paper_id, 
                label=f"{title}", 
                title=tooltip_text,  # Tooltip on hover
                color="darkred", 
                size=50, 
                font={"size": 30, "bold": True}, 
                physics=False  # Fix the root node in place
            )
        else:
            net.add_node(
                paper_id, 
                label=title, 
                title=tooltip_text,  # Tooltip on hover
                color="pink", 
                size=15, 
                font={"size": 12}
            )
        
        G.add_node(paper_id)

    # Add edges
    for cited_paper_id, citing_paper_id in citation_edges:
        net.add_edge(citing_paper_id, cited_paper_id)
        G.add_edge(citing_paper_id, cited_paper_id)

    # Save and show
    file_name = f"NIT_citation_graph_{paper_num}.html"
    net.show(file_name)
    print(f"Graph saved as {file_name}")

    return G  # Return networkx graph for analysis

# Load stored citation data
citation_data = load_data()

# Generate and visualize graphs
graphs = {}  # Store networkx graphs
for idx, root_paper_id in enumerate(citation_data.keys()):
    citation_edges = citation_data[root_paper_id]["edges"]
    citation_dict = citation_data[root_paper_id]["dict"]
    author_dict = citation_data[root_paper_id].get("authors", {})  # Get authors if available
    graphs[root_paper_id] = draw_graph_pyvis(root_paper_id, citation_edges, citation_dict, author_dict, idx + 1)

print("\nGraphs generated and saved.")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# NIT_citation_graph_1.html
# Graph saved as NIT_citation_graph_1.html
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# NIT_citation_graph_2.html
# Graph saved as NIT_citation_graph_2.html
#
# Graphs generated and saved.

# %%
# Function to compute network measures
def compute_measures(G, paper_num):
    print(f"\n Network Measures for Paper {paper_num}")

    # Get the citation_dict for the current root paper
    root_paper_id = list(citation_data.keys())[paper_num-1]
    citation_dict = citation_data[root_paper_id]["dict"]

    # Function to convert a (paper_id, score) tuple to (paper_title, score)
    def id_to_title(item):
        paper_id, score = item
        title = citation_dict.get(paper_id, f"Unknown Title (ID: {paper_id})")
        return (title, score)

    # Compute Diameter
    if nx.is_strongly_connected(G):
        diameter = nx.diameter(G)
        print(f"Graph Diameter: {diameter}")
    else:
        print("Graph is not strongly connected. Diameter cannot be computed.")
        sccs = list(nx.strongly_connected_components(G))
        largest_scc = max(sccs, key=len)
        G_scc = G.subgraph(largest_scc)
        diameter_scc = nx.diameter(G_scc)
        print(f"Diameter of the Largest Strongly Connected Component: {diameter_scc}")

    # Centrality Measures
    degree_centrality = nx.degree_centrality(G)
    closeness_centrality = nx.closeness_centrality(G)
    betweenness_centrality = nx.betweenness_centrality(G)
    eigenvector_centrality = nx.eigenvector_centrality(G, max_iter=1000)
    pagerank = nx.pagerank(G)

    print("\nTop 5 Nodes by Degree Centrality:")
    top_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:5]
    print([id_to_title(item) for item in top_degree])

    print("\nTop 5 Nodes by Closeness Centrality:")
    top_closeness = sorted(closeness_centrality.items(), key=lambda x: x[1], reverse=True)[:5]
    print([id_to_title(item) for item in top_closeness])

    print("\nTop 5 Nodes by Betweenness Centrality:")
    top_betweenness = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)[:5]
    print([id_to_title(item) for item in top_betweenness])

    print("\nTop 5 Nodes by Eigenvector Centrality:")
    top_eigenvector = sorted(eigenvector_centrality.items(), key=lambda x: x[1], reverse=True)[:5]
    print([id_to_title(item) for item in top_eigenvector])

    print("\nTop 5 Nodes by PageRank:")
    top_pagerank = sorted(pagerank.items(), key=lambda x: x[1], reverse=True)[:5]
    print([id_to_title(item) for item in top_pagerank])

    # HITS Algorithm
    hubs, authorities = nx.hits(G)
    print("\nTop 5 Nodes by Hub Score:")
    top_hubs = sorted(hubs.items(), key=lambda x: x[1], reverse=True)[:5]
    print([id_to_title(item) for item in top_hubs])

    print("\nTop 5 Nodes by Authority Score:")
    top_authorities = sorted(authorities.items(), key=lambda x: x[1], reverse=True)[:5]
    print([id_to_title(item) for item in top_authorities])

    # Clustering Coefficients
    global_clustering = nx.average_clustering(G)
    local_clustering = nx.clustering(G)

    print(f"\nGlobal Clustering Coefficient: {global_clustering}")

    print("\nTop 5 Nodes by Local Clustering Coefficient:")
    top_clustering = sorted(local_clustering.items(), key=lambda x: x[1], reverse=True)[:5]
    print([id_to_title(item) for item in top_clustering])

    # Connected Components
    if nx.is_directed(G):
        weakly_connected_components = list(nx.weakly_connected_components(G))
        print(f"\nNumber of Weakly Connected Components: {len(weakly_connected_components)}")
    else:
        connected_components = list(nx.connected_components(G))
        print(f"\nNumber of Connected Components: {len(connected_components)}")

# Compute network measures for each graph
for idx, root_paper_id in enumerate(citation_data):
    compute_measures(graphs[root_paper_id], idx + 1)
# Out:
#  Network Measures for Paper 1
# Graph is not strongly connected. Diameter cannot be computed.
# Diameter of the Largest Strongly Connected Component: 0
#
# Top 5 Nodes by Degree Centrality:
# [('Resource management in pervasive Internet of Things: A survey', 0.5877862595419847), ('BlockFaaS: Blockchain-enabled Serverless Computing Framework for AI-driven IoT Healthcare Applications', 0.08396946564885496), ('The internet of medical things in healthcare management: a review', 0.06870229007633588), ('Optimization of Maritime Communication Workflow Execution with a Task-Oriented Scheduling Framework in Cloud Computing', 0.05343511450381679), ('Linear Interval Approximation of Sensor Characteristics with Inflection Points', 0.04580152671755725)]
#
# Top 5 Nodes by Closeness Centrality:
# [('An efficient medical data encryption scheme using selective shuffling and inter-intra pixel diffusion IoT-enabled secure E-healthcare framework', 0.010178117048346055), ('A risk assessment method for power internet of things information security based on multi‐objective hierarchical optimisation', 0.010178117048346055), ('An intelligent cyber-physical system based-consensus algorithm for sustainable edge service provisioning in 6G-based IIoT applications', 0.010178117048346055), ('Cognitive Transformation in Personal IoT: Pioneering Intelligent Automation', 0.010178117048346055), ('Machine learning and flavoromics-based research strategies for determining the characteristic flavor of food: A review', 0.010178117048346055)]
#
# Top 5 Nodes by Betweenness Centrality:
# [('BlockFaaS: Blockchain-enabled Serverless Computing Framework for AI-driven IoT Healthcare Applications', 0.0005871990604815032), ('The internet of medical things in healthcare management: a review', 0.0004697592483852026), ('Optimization of Maritime Communication Workflow Execution with a Task-Oriented Scheduling Framework in Cloud Computing', 0.00035231943628890195), ('Linear Interval Approximation of Sensor Characteristics with Inflection Points', 0.0002935995302407516), ('A systematic review of applying grey wolf optimizer, its variants, and its developments in different Internet of Things applications', 0.0002348796241926013)]
#
# Top 5 Nodes by Eigenvector Centrality:
# [('An efficient medical data encryption scheme using selective shuffling and inter-intra pixel diffusion IoT-enabled secure E-healthcare framework', 0.1360803380638328), ('A risk assessment method for power internet of things information security based on multi‐objective hierarchical optimisation', 0.1360803380638328), ('An intelligent cyber-physical system based-consensus algorithm for sustainable edge service provisioning in 6G-based IIoT applications', 0.1360803380638328), ('Cognitive Transformation in Personal IoT: Pioneering Intelligent Automation', 0.1360803380638328), ('Machine learning and flavoromics-based research strategies for determining the characteristic flavor of food: A review', 0.1360803380638328)]
#
# Top 5 Nodes by PageRank:
# [('An efficient medical data encryption scheme using selective shuffling and inter-intra pixel diffusion IoT-enabled secure E-healthcare framework', 0.012757791896640438), ('Machine learning and flavoromics-based research strategies for determining the characteristic flavor of food: A review', 0.012757791896640438), ('Dynamic Resource Allocation for IoT-Fog Architectures Leveraging Differential Services and Adaptive QoS Models', 0.012757791896640438), ('Power allocation method based on modified social network search algorithm', 0.012757791896640438), ('Quantum Optimization for Energy Management: A Coherent Variational Approach', 0.009809670813948443)]
#
# Top 5 Nodes by Hub Score:
# [('Resource management in pervasive Internet of Things: A survey', 1.0), ('A systematic review of applying grey wolf optimizer, its variants, and its developments in different Internet of Things applications', 5.195330895201879e-17), ('Exploring Personalized Internet of Things (PIoT), social connectivity, and Artificial Social Intelligence (ASI): A survey', 2.1107834042565058e-17), ('Optimization of Maritime Communication Workflow Execution with a Task-Oriented Scheduling Framework in Cloud Computing', 2.0382145693297312e-17), ('Intelligent resource allocation decision using deep learning and optimization techniques for HetNets', 7.131460895508095e-18)]
#
# Top 5 Nodes by Authority Score:
# [('An ontology-based system for discovering landslide-induced emergencies in electrical grid', 0.012987012987012995), ('"A systematic literature review on IoT gateways"', 0.012987012987012993), ('GBDT-IL: Incremental Learning of Gradient Boosting Decision Trees to Detect Botnets in Internet of Things', 0.012987012987012991), ('A systematic review of applying grey wolf optimizer, its variants, and its developments in different Internet of Things applications', 0.012987012987012991), ('Deep Image Semantic Communication Model for Artificial Intelligent Internet of Things', 0.012987012987012991)]
#
# Global Clustering Coefficient: 0.0
#
# Top 5 Nodes by Local Clustering Coefficient:
# [('Resource management in pervasive Internet of Things: A survey', 0), ('Text-and-timbre-based speech semantic coding for ultra-low-bitrate communications', 0), ('Enhancing Internet of Things communications: Development of a new S-box and multi-layer encryption framework', 0), ('Exploring Personalized Internet of Things (PIoT), social connectivity, and Artificial Social Intelligence (ASI): A survey', 0), ('A greedy randomized adaptive search procedure for scheduling IoT tasks in virtualized fog–cloud computing', 0)]
#
# Number of Weakly Connected Components: 1
#
#  Network Measures for Paper 2
# Graph is not strongly connected. Diameter cannot be computed.
# Diameter of the Largest Strongly Connected Component: 0
#
# Top 5 Nodes by Degree Centrality:
# [('Applicability of Blockchain smart contracts in securing Internet and IoT: A systematic literature review', 0.5447761194029851), ('Blockchain-based secure dining: Enhancing safety, transparency, and traceability in food consumption environment', 0.15671641791044777), ('Exploring the integration of edge computing and blockchain IoT: Principles, architectures, security, and applications', 0.09701492537313433), ('MSLShard: An efficient sharding-based trust management framework for blockchain-empowered IoT access control', 0.05970149253731343), ('Unlocking the potential of blockchain technology in enhancing the fisheries supply chain: an exploration of critical adoption barriers in China', 0.05223880597014925)]
#
# Top 5 Nodes by Closeness Centrality:
# [('Blockchain-based digital product passport: design principles and demonstration', 0.009950248756218905), ('ParaBFT: An Efficient Parallel Asynchronous BFT Agreement', 0.009950248756218905), ('Current research on Internet of Things (IoT) security protocols: A survey', 0.009950248756218905), ('A Survey on Physical Layer Security for 5G/6G Communications over Different Fading Channels: Approaches, Challenges, and Future Directions', 0.009950248756218905), ('The Future of Food Security: The Role of Blockchain Technology in Global Aquaculture', 0.009950248756218905)]
#
# Top 5 Nodes by Betweenness Centrality:
# [('Blockchain-based secure dining: Enhancing safety, transparency, and traceability in food consumption environment', 0.0011222085063404782), ('Exploring the integration of edge computing and blockchain IoT: Principles, architectures, security, and applications', 0.0006733251038042869), ('MSLShard: An efficient sharding-based trust management framework for blockchain-empowered IoT access control', 0.00039277297721916735), ('Unlocking the potential of blockchain technology in enhancing the fisheries supply chain: an exploration of critical adoption barriers in China', 0.00033666255190214345), ('Distributed ledger technologies for authentication and access control in networking applications: A comprehensive survey', 0.00033666255190214345)]
#
# Top 5 Nodes by Eigenvector Centrality:
# [('Blockchain-based digital product passport: design principles and demonstration', 0.12803468919001781), ('ParaBFT: An Efficient Parallel Asynchronous BFT Agreement', 0.12803468919001781), ('Current research on Internet of Things (IoT) security protocols: A survey', 0.12803468919001781), ('A Survey on Physical Layer Security for 5G/6G Communications over Different Fading Channels: Approaches, Challenges, and Future Directions', 0.12803468919001781), ('The Future of Food Security: The Role of Blockchain Technology in Global Aquaculture', 0.12803468919001781)]
#
# Top 5 Nodes by PageRank:
# [('LESP:A fault-aware internet of things service placement in fog computing', 0.0128757518216798), ('Blockchain-based digital product passport: design principles and demonstration', 0.009899308424215216), ('ParaBFT: An Efficient Parallel Asynchronous BFT Agreement', 0.009899308424215216), ('Current research on Internet of Things (IoT) security protocols: A survey', 0.009899308424215216), ('A Survey on Physical Layer Security for 5G/6G Communications over Different Fading Channels: Approaches, Challenges, and Future Directions', 0.009899308424215216)]
#
# Top 5 Nodes by Hub Score:
# [('Applicability of Blockchain smart contracts in securing Internet and IoT: A systematic literature review', 1.0), ('Blockchain-based secure dining: Enhancing safety, transparency, and traceability in food consumption environment', 1.1391524515060998e-17), ('Unlocking the potential of blockchain technology in enhancing the fisheries supply chain: an exploration of critical adoption barriers in China', 3.8861492816629985e-18), ('A survey on security issues in IoT operating systems', 1.0432959140241387e-20), ('Improving IoT Management with Blockchain: Smart Home Access Control', -0.0)]
#
# Top 5 Nodes by Authority Score:
# [('Exploring the integration of edge computing and blockchain IoT: Principles, architectures, security, and applications', 0.01369863013698631), ('Barriers to blockchain technology adoption in supply chains: the case of India', 0.01369863013698631), ('COLLABORATIVE VALIDATION OF USER-CONTRIBUTED DATA USING A GEOSPATIAL BLOCKCHAIN APPROACH: THE SIMILE CASE STUDY', 0.01369863013698631), ('Factors Influencing the Behavioural Intention to Use Cryptocurrency in Emerging Economies During the COVID-19 Pandemic: Based on Technology Acceptance Model 3, Perceived Risk, and Financial Literacy', 0.01369863013698631), ('An assessment of blockchain academia and news developments:\xa0a bibliometric and\xa0text-mining analysis', 0.013698630136986308)]
#
# Global Clustering Coefficient: 0.0
#
# Top 5 Nodes by Local Clustering Coefficient:
# [('Applicability of Blockchain smart contracts in securing Internet and IoT: A systematic literature review', 0), ('Improving IoT Management with Blockchain: Smart Home Access Control', 0), ('Distributed Databases for Computer Applications: Study and Selection of Distributed Ledger Technologies', 0), ('Leveraging the usage of blockchain toward trust-dominated manufacturing systems', 0), ('Exploring IoT and Blockchain: A Comprehensive Survey on Security, Integration Strategies, Applications and Future Research Directions', 0)]
#
# Number of Weakly Connected Components: 1
